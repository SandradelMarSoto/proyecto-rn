# %% [markdown]
# # Facultad de Ciencias, UNAM.
# # Proyecto Redes Neuronales:
#
# ## Clasificador de géneros musicales
#
# ### Integrantes:
# - Jorge Francisco Cortés López - 314330981
# - Sandra del Mar Soto Corderi - 3157070267

# %% [markdown]
# ## Introducción y motivación.
# Uno de los retos más interesantes para la inteligencia artificial es el de intentar que clasifiquemos o generemos arte usando diferentes herramientas como las redes neuronales, ya que hasta la fecha no existe un algoritmo o clasificador en el que pasemos una canción o ciertos atributos de una canción y nos diga a qué género pertenece. Actualmente existen muchos géneros y cada vez es más difícil clasificar objetivamente a qué género corresponde una canción.
#
# Así que para éste proyecto intentamos ver hasta donde podemos llegar a clasificar el conjunto de canciones que obtuvimos con ciertas características musicales como: tono, tiempo, tempo, popularidad, entre otros.
#
# Se utilizó una red multicapa, ya que queríamos ver hasta donde podíamos explotar sus capacidades, existen otras arquitecturas más modernas como las redes convolucionales, sin embargo era mucho más complejo y difícil obtener los datos adecuados para estos modelos, por lo que decidimos optar por una arquitectura más sencilla y ver hasta donde nos podía llevar.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# Si se tiene GPU Nvidia se puede descomentar.
#device = "cuda"
device = "cpu"

# %% [markdown]
# # Procesamiento de datos
# Lo primero que hacemos es cargar los datos con ayuda de la biblioteca pandas, que es de mucha utilidad para cargar y manipular datos en python.
#
# Analizamos varias bibliotecas de datos sobre canciones y terminamos escogiendo la de https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db, ya que contaba con datos bastante limpios y fáciles de manejar. Así mismo era una cantidad muy buena para lo que queremos lograr.
#
# Mostramos un sample de los datos.

# %%
music_data = 'data/musicdata.csv'
music_data = pd.read_csv(music_data)
music_data.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %% [markdown]
# ## Limpieza de datos
# Vemos si existen canciones duplicadas en diferentes géneros, en éste caso hay canciones que están en varios géneros, por lo que lo mejor será dejarlas solo con el primer género en que aparecen.
#
# Además de ésto, después de varias ejecuciones de nuestra red encontramos que algunos géneros no se usaban prácticamente con nuestro conjunto de datos, es decir que no contaban con muchas canciones por lo que los quitamos y observamos un mejoramiento en los resultados.

# %%
# Duplicados
music_data = music_data.drop_duplicates(subset=['track_name'], keep='first', ignore_index=True)

# Géneros que consideramos para quitar 
# (Muchas canciones de Hip Hop se pueden categorizar como Rap)
music_data.drop(music_data[music_data.genre == 'Rap'].index, inplace=True)
music_data.drop(music_data[music_data.genre == 'Children\'s Music'].index, inplace=True)
music_data.drop(music_data[music_data.genre == 'Children’s Music'].index, inplace=True)
music_data.drop(music_data[music_data.genre == 'A Capella'].index, inplace=True)
music_data.drop(music_data[music_data.genre == 'Indie'].index, inplace=True)

# %% [markdown]
# Quitamos también las características que no nos interesan, en éste caso:
#
# * artist_name
# * track_name
# * track_id
# * duration_ms
#
# no nos interesan, ya que ésto en un principio no tendría porqué influenciar el género de una canción.

# %%
unused_col = ['artist_name', 'track_name', 'track_id', 'duration_ms']
music_data = music_data.drop(columns=unused_col)

# %% [markdown]
# Finalmente, vemos si hay ejemplares que tengan algún dato faltante.

# %%
music_data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Codificación y normalización
# Una vez que nuestros datos están limpios podemos hacer la codificación para nuestra red neuronal, vemos que hay algunos datos que necesitan ser normalizados como popularity, loudness y tempo. Sin embargo también vemos que key, mode y time signature necesitan ser codificados.

# %%
# Normalizamos las columnas correspondientes.
mms = MinMaxScaler()
music_data[['popularity','loudness','tempo']] = \
            mms.fit_transform(music_data[['popularity','loudness','tempo']])

# %%
# Codificamos a One hot encoding las columnas necesarias.
music_data = \
    pd.get_dummies(data=music_data, columns=['key', 'mode', 'time_signature'], dtype=float)

# %% [markdown]
# Luego de codificar y normalizar los ejemplares, codificamos igualmente las clases con ayuda de la clase LabelEncoder.

# %%
le = LabelEncoder()
music_data['genre'] = le.fit_transform(music_data.genre.values).astype(float)

# %% [markdown]
# Finalmente vemos cómo quedaron las columnas de los datos ya procesados y limpios para proseguir con los demás pasos

# %%
music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139919 entries, 0 to 148614
# Data columns (total 30 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   genre               139919 non-null  float64
#  1   popularity          139919 non-null  float64
#  2   acousticness        139919 non-null  float64
#  3   danceability        139919 non-null  float64
#  4   energy              139919 non-null  float64
#  5   instrumentalness    139919 non-null  float64
#  6   liveness            139919 non-null  float64
#  7   loudness            139919 non-null  float64
#  8   speechiness         139919 non-null  float64
#  9   tempo               139919 non-null  float64
#  10  valence             139919 non-null  float64
#  11  key_A               139919 non-null  float64
#  12  key_A#              139919 non-null  float64
#  13  key_B               139919 non-null  float64
#  14  key_C               139919 non-null  float64
#  15  key_C#              139919 non-null  float64
#  16  key_D               139919 non-null  float64
#  17  key_D#              139919 non-null  float64
#  18  key_E               139919 non-null  float64
#  19  key_F               139919 non-null  float64
#  20  key_F#              139919 non-null  float64
#  21  key_G               139919 non-null  float64
#  22  key_G#              139919 non-null  float64
#  23  mode_Major          139919 non-null  float64
#  24  mode_Minor          139919 non-null  float64
#  25  time_signature_0/4  139919 non-null  float64
#  26  time_signature_1/4  139919 non-null  float64
#  27  time_signature_3/4  139919 non-null  float64
#  28  time_signature_4/4  139919 non-null  float64
#  29  time_signature_5/4  139919 non-null  float64
# dtypes: float64(30)
# memory usage: 33.1 MB

# %% [markdown]
# ## División del conjunto de datos
# Una vez que hemos limpiado el conjunto de datos proseguimos a hacer la división en los conjuntos de entrenamiento y prueba.

# %%
Y = music_data.pop('genre')
X = music_data

# %%
# Hacemos la división con una proporción de 70% - 30%.
X_train, X_test, y_train, y_test = \
    train_test_split(X, Y, test_size=0.3,random_state=7, stratify=Y)

# %% [markdown]
# # Clase de dataset para Pytorch
# Una vez que ya tenemos los datos separados, creamos la clase que hereda de Dataset en pytorch para facilitar el flujo entre la red neuronal y poder hacer el entrenamiento en lotes (batches).

# %%
class MusicDataset(Dataset):
    """Dataset de música de spotify"""
    
    def __init__(self, X, Y):
        """
        Args:
            X (pandas DataFrame): Datos.
            Y (pandas DataFrame): Labels.
        """
        self.X = X
        self.Y = Y
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        features = np.asarray(self.X.iloc[idx])
        label = np.asarray(self.Y.iloc[idx])
        return features, label

# %% [markdown]
# ## Instancias de objetos de datos para pytorch
# Una vez creada la clase para los datos de música, los instanciamos con el conjunto de entrenamiento y de prueba para pytorch como DataLoader.

# %%
# Entrenamiento:
trainset = MusicDataset(X = X_train, Y = y_train)
trainset = DataLoader(trainset, batch_size=15000) # Podemos cambiar el número de lotes.

# Prueba:
testset = MusicDataset(X = X_test, Y = y_test)
testset = DataLoader(testset, batch_size=5000)

# %% [markdown]
# # Modelo
# Ya teniendo los datos como DataLoader ahora nos enfocamos en el modelo.
#
# En éste proyecto decidimos utilizar la arquitectura de perceptrón multicapa, a continuación definimos el modelo y posteriormente haremos el entrenamiento de la red.
# Tenemos: 29 características de entrada y 22 de salida (22 géneros en total).
# Cada capa oculta cuenta con 350 neuronas. A continuación definimos y mostramos el modelo.

# %% [markdown]
# <img src="images/nn.svg">

# %%
class Musica(nn.Module):
    def __init__(self,input_size,hidden,output_size):
        '''
        Define las caracteristicas de una red completamente conectada 
        de tres capas, recibe la cantidad de elementos de entrada, el 
        número de capas ocultas y el número de elementos de salida. 
        Entre cada capa agrega una función de activación relu.
        '''
        super(Musica,self).__init__()
        #Declaramos las tres capas 
        self.fc1 = nn.Linear(input_size, hidden)
        self.fc2 = nn.Linear(hidden, hidden)
        self.fc3 = nn.Linear(hidden, hidden)
        self.fc4 = nn.Linear(hidden, output_size) 
        # Función de error.
        self.loss_fn = nn.CrossEntropyLoss()
        # Algoritmo de optimización.
        self.optimizer = optim.Adam(self.parameters(), lr=0.0005)
        # Error actual de la red.
        self.loss = 0.0
        
    def forward(self,X):
        '''
        Define una función que de como resultado realizar la propagación
        hacia adelante de los elementos de X en la red definida.
        '''
        #Se activa la capa de entrada
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = F.relu(self.fc3(X))
        X = self.fc4(X)
        
        return F.log_softmax(X, dim=1)
        
    def back_propagate(self,X,Y):
        '''
        Define una función que realice la propagación hacia atras usando 
        la función de error de entropia cruzada.
        '''
        # Calculamos el error.
        self.loss = self.loss_fn(X,Y.long())
        
        #Vaciamos los gradientes, hacemos una propagación hacia atrás
        # y actualizamos pesos.
        self.optimizer.zero_grad()
        self.loss.backward()
        self.optimizer.step()
        
    def train(self,train_X,ciclos=100):
        '''
        Define una función de entrenamiento para la red, la cual utilice
        al conjunto de entrenamiento y el algoritmo de optimización que se 
        obtenga como parametro. Al finalizar los ciclos muestra la gráfica 
        del error.
        '''
        data_error = np.zeros(ciclos)
        
        for t in range(ciclos):
            # Para cada uno de los lotes.
            for data in train_X:
                X, Y = data
                X, Y = X.to(device), Y.to(device)
                
                # Feed forward.
                y_pred = self(X.float())
                
                # Back propagate.
                self.back_propagate(y_pred, Y)
                
                # Anexamos el error actual.
                data_error[t] = self.loss
            print("Error en la iteración: " + str(t) + " " + str(self.loss))
        
        # Graficamos el error.
        if ciclos > 1:
            plt.plot(np.arange(ciclos), data_error)
            plt.xlabel('Iteraciones')
            plt.ylabel('Error')
                
    def confusion(self,dataset,numClases):
        '''
        Muestra la matriz de confusión que presenta los valores actuales de
        la red, respecto al conjunto de datos que se decida usar.
        '''
        # Matriz de confusión inicial con dimensión correspondiente al número de clases.
        cmatrix = np.zeros([numClases,numClases], dtype=int)
        for data in dataset:
            X,Y = data
            X, Y = X.to(device), Y.to(device)
            #Se obtienen las predicciones de la data
            y_pred = self.forward(X.float())
            _, predicted = torch.max(y_pred.data, 1)
            # Se juntan los datos para obtener predicciones de las clases.
            stacked = torch.stack((predicted ,Y),dim=1)
            # Iteramos sobre las predicciones y las clases.
            for p in stacked:
                tl, pl = p.tolist()
                cmatrix[int(tl), int(pl)] = cmatrix[int(tl), int(pl)] + 1
        # Una vez calculada la matriz se grafica
        music_labels = le.classes_
        df_cm = pd.DataFrame(cmatrix, index = music_labels, columns = music_labels)
        plt.figure(figsize = (20,15))
        sns.set_theme(style="whitegrid")
        #Por cuestiones de estética y facilidad se usa heatmap
        sns.heatmap(df_cm, annot=True, robust=True, fmt="d", cmap="YlGnBu")
        plt.title("Matriz de confusión sin normalizar")
        plt.ylabel('Predicción')
        plt.xlabel('Actual')
        plt.show()
        
    # Accuracy de un conjunto de datos dentro de la RN.
    def accurNet(self, dataTest):
        correct = 0
        total = 0
        with torch.no_grad():
            for data in dataTest:
                X, Y = data
                X, Y = X.to(device), Y.to(device)

                y_pred = self.forward(X.float())

                _, predicted = torch.max(y_pred.data, 1)
                predicted = predicted.float()
                total += Y.size(0)
                correct += (predicted == Y).sum().item()
        return 100 * correct / total

# %% [markdown]
# # Entrenamiento
# A continuación creamos una instancia de la red neuronal y hacemos el entrenamiento.

# %%
# Instanciamos la red.
nn_Musica = Musica(29, 350, 22)
#nn_Musica.cuda() # Para cuda.

# %%
nn_Musica.train(trainset, ciclos=1000)
# Out:
# Error en la iteración: 0 tensor(3.0436, grad_fn=<NllLossBackward>)
# Error en la iteración: 1 tensor(2.9445, grad_fn=<NllLossBackward>)
# Error en la iteración: 2 tensor(2.7842, grad_fn=<NllLossBackward>)
# Error en la iteración: 3 tensor(2.5473, grad_fn=<NllLossBackward>)
# Error en la iteración: 4 tensor(2.3744, grad_fn=<NllLossBackward>)
# Error en la iteración: 5 tensor(2.2616, grad_fn=<NllLossBackward>)
# Error en la iteración: 6 tensor(2.1726, grad_fn=<NllLossBackward>)
# Error en la iteración: 7 tensor(2.0844, grad_fn=<NllLossBackward>)
# Error en la iteración: 8 tensor(1.9879, grad_fn=<NllLossBackward>)
# Error en la iteración: 9 tensor(1.8974, grad_fn=<NllLossBackward>)
# Error en la iteración: 10 tensor(1.8290, grad_fn=<NllLossBackward>)
# Error en la iteración: 11 tensor(1.7838, grad_fn=<NllLossBackward>)
# Error en la iteración: 12 tensor(1.7516, grad_fn=<NllLossBackward>)
# Error en la iteración: 13 tensor(1.7291, grad_fn=<NllLossBackward>)
# Error en la iteración: 14 tensor(1.7116, grad_fn=<NllLossBackward>)
# Error en la iteración: 15 tensor(1.6978, grad_fn=<NllLossBackward>)
# Error en la iteración: 16 tensor(1.6875, grad_fn=<NllLossBackward>)
# Error en la iteración: 17 tensor(1.6793, grad_fn=<NllLossBackward>)
# Error en la iteración: 18 tensor(1.6729, grad_fn=<NllLossBackward>)
# Error en la iteración: 19 tensor(1.6675, grad_fn=<NllLossBackward>)
# Error en la iteración: 20 tensor(1.6615, grad_fn=<NllLossBackward>)
# Error en la iteración: 21 tensor(1.6550, grad_fn=<NllLossBackward>)
# Error en la iteración: 22 tensor(1.6495, grad_fn=<NllLossBackward>)
# Error en la iteración: 23 tensor(1.6439, grad_fn=<NllLossBackward>)
# Error en la iteración: 24 tensor(1.6385, grad_fn=<NllLossBackward>)
# Error en la iteración: 25 tensor(1.6332, grad_fn=<NllLossBackward>)
# Error en la iteración: 26 tensor(1.6279, grad_fn=<NllLossBackward>)
# Error en la iteración: 27 tensor(1.6228, grad_fn=<NllLossBackward>)
# Error en la iteración: 28 tensor(1.6179, grad_fn=<NllLossBackward>)
# Error en la iteración: 29 tensor(1.6130, grad_fn=<NllLossBackward>)
# Error en la iteración: 30 tensor(1.6084, grad_fn=<NllLossBackward>)
# Error en la iteración: 31 tensor(1.6038, grad_fn=<NllLossBackward>)
# Error en la iteración: 32 tensor(1.5994, grad_fn=<NllLossBackward>)
# Error en la iteración: 33 tensor(1.5952, grad_fn=<NllLossBackward>)
# Error en la iteración: 34 tensor(1.5910, grad_fn=<NllLossBackward>)
# Error en la iteración: 35 tensor(1.5871, grad_fn=<NllLossBackward>)
# Error en la iteración: 36 tensor(1.5832, grad_fn=<NllLossBackward>)
# Error en la iteración: 37 tensor(1.5793, grad_fn=<NllLossBackward>)
# Error en la iteración: 38 tensor(1.5757, grad_fn=<NllLossBackward>)
# Error en la iteración: 39 tensor(1.5721, grad_fn=<NllLossBackward>)
# Error en la iteración: 40 tensor(1.5687, grad_fn=<NllLossBackward>)
# Error en la iteración: 41 tensor(1.5653, grad_fn=<NllLossBackward>)
# Error en la iteración: 42 tensor(1.5620, grad_fn=<NllLossBackward>)
# Error en la iteración: 43 tensor(1.5587, grad_fn=<NllLossBackward>)
# Error en la iteración: 44 tensor(1.5556, grad_fn=<NllLossBackward>)
# Error en la iteración: 45 tensor(1.5526, grad_fn=<NllLossBackward>)
# Error en la iteración: 46 tensor(1.5496, grad_fn=<NllLossBackward>)
# Error en la iteración: 47 tensor(1.5468, grad_fn=<NllLossBackward>)
# Error en la iteración: 48 tensor(1.5439, grad_fn=<NllLossBackward>)
# Error en la iteración: 49 tensor(1.5411, grad_fn=<NllLossBackward>)
# Error en la iteración: 50 tensor(1.5384, grad_fn=<NllLossBackward>)
# Error en la iteración: 51 tensor(1.5357, grad_fn=<NllLossBackward>)
# Error en la iteración: 52 tensor(1.5331, grad_fn=<NllLossBackward>)
# Error en la iteración: 53 tensor(1.5305, grad_fn=<NllLossBackward>)
# Error en la iteración: 54 tensor(1.5279, grad_fn=<NllLossBackward>)
# Error en la iteración: 55 tensor(1.5254, grad_fn=<NllLossBackward>)
# Error en la iteración: 56 tensor(1.5230, grad_fn=<NllLossBackward>)
# Error en la iteración: 57 tensor(1.5206, grad_fn=<NllLossBackward>)
# Error en la iteración: 58 tensor(1.5182, grad_fn=<NllLossBackward>)
# Error en la iteración: 59 tensor(1.5159, grad_fn=<NllLossBackward>)
# Error en la iteración: 60 tensor(1.5136, grad_fn=<NllLossBackward>)
# Error en la iteración: 61 tensor(1.5113, grad_fn=<NllLossBackward>)
# Error en la iteración: 62 tensor(1.5091, grad_fn=<NllLossBackward>)
# Error en la iteración: 63 tensor(1.5068, grad_fn=<NllLossBackward>)
# Error en la iteración: 64 tensor(1.5046, grad_fn=<NllLossBackward>)
# Error en la iteración: 65 tensor(1.5025, grad_fn=<NllLossBackward>)
# Error en la iteración: 66 tensor(1.5003, grad_fn=<NllLossBackward>)
# Error en la iteración: 67 tensor(1.4982, grad_fn=<NllLossBackward>)
# Error en la iteración: 68 tensor(1.4960, grad_fn=<NllLossBackward>)
# Error en la iteración: 69 tensor(1.4938, grad_fn=<NllLossBackward>)
# Error en la iteración: 70 tensor(1.4917, grad_fn=<NllLossBackward>)
# Error en la iteración: 71 tensor(1.4896, grad_fn=<NllLossBackward>)
# Error en la iteración: 72 tensor(1.4875, grad_fn=<NllLossBackward>)
# Error en la iteración: 73 tensor(1.4853, grad_fn=<NllLossBackward>)
# Error en la iteración: 74 tensor(1.4833, grad_fn=<NllLossBackward>)
# Error en la iteración: 75 tensor(1.4813, grad_fn=<NllLossBackward>)
# Error en la iteración: 76 tensor(1.4793, grad_fn=<NllLossBackward>)
# Error en la iteración: 77 tensor(1.4774, grad_fn=<NllLossBackward>)
# Error en la iteración: 78 tensor(1.4754, grad_fn=<NllLossBackward>)
# Error en la iteración: 79 tensor(1.4735, grad_fn=<NllLossBackward>)
# Error en la iteración: 80 tensor(1.4717, grad_fn=<NllLossBackward>)
# Error en la iteración: 81 tensor(1.4698, grad_fn=<NllLossBackward>)
# Error en la iteración: 82 tensor(1.4681, grad_fn=<NllLossBackward>)
# Error en la iteración: 83 tensor(1.4663, grad_fn=<NllLossBackward>)
# Error en la iteración: 84 tensor(1.4645, grad_fn=<NllLossBackward>)
# Error en la iteración: 85 tensor(1.4627, grad_fn=<NllLossBackward>)
# Error en la iteración: 86 tensor(1.4610, grad_fn=<NllLossBackward>)
# Error en la iteración: 87 tensor(1.4592, grad_fn=<NllLossBackward>)
# Error en la iteración: 88 tensor(1.4575, grad_fn=<NllLossBackward>)
# Error en la iteración: 89 tensor(1.4558, grad_fn=<NllLossBackward>)
# Error en la iteración: 90 tensor(1.4541, grad_fn=<NllLossBackward>)
# Error en la iteración: 91 tensor(1.4524, grad_fn=<NllLossBackward>)
# Error en la iteración: 92 tensor(1.4508, grad_fn=<NllLossBackward>)
# Error en la iteración: 93 tensor(1.4492, grad_fn=<NllLossBackward>)
# Error en la iteración: 94 tensor(1.4476, grad_fn=<NllLossBackward>)
# Error en la iteración: 95 tensor(1.4460, grad_fn=<NllLossBackward>)
# Error en la iteración: 96 tensor(1.4443, grad_fn=<NllLossBackward>)
# Error en la iteración: 97 tensor(1.4428, grad_fn=<NllLossBackward>)
# Error en la iteración: 98 tensor(1.4411, grad_fn=<NllLossBackward>)
# Error en la iteración: 99 tensor(1.4395, grad_fn=<NllLossBackward>)
# Error en la iteración: 100 tensor(1.4379, grad_fn=<NllLossBackward>)
# Error en la iteración: 101 tensor(1.4365, grad_fn=<NllLossBackward>)
# Error en la iteración: 102 tensor(1.4349, grad_fn=<NllLossBackward>)
# Error en la iteración: 103 tensor(1.4333, grad_fn=<NllLossBackward>)
# Error en la iteración: 104 tensor(1.4317, grad_fn=<NllLossBackward>)
# Error en la iteración: 105 tensor(1.4302, grad_fn=<NllLossBackward>)
# Error en la iteración: 106 tensor(1.4287, grad_fn=<NllLossBackward>)
# Error en la iteración: 107 tensor(1.4272, grad_fn=<NllLossBackward>)
# Error en la iteración: 108 tensor(1.4257, grad_fn=<NllLossBackward>)
# Error en la iteración: 109 tensor(1.4243, grad_fn=<NllLossBackward>)
# Error en la iteración: 110 tensor(1.4229, grad_fn=<NllLossBackward>)
# Error en la iteración: 111 tensor(1.4215, grad_fn=<NllLossBackward>)
# Error en la iteración: 112 tensor(1.4201, grad_fn=<NllLossBackward>)
# Error en la iteración: 113 tensor(1.4187, grad_fn=<NllLossBackward>)
# Error en la iteración: 114 tensor(1.4175, grad_fn=<NllLossBackward>)
# Error en la iteración: 115 tensor(1.4160, grad_fn=<NllLossBackward>)
# Error en la iteración: 116 tensor(1.4147, grad_fn=<NllLossBackward>)
# Error en la iteración: 117 tensor(1.4134, grad_fn=<NllLossBackward>)
# Error en la iteración: 118 tensor(1.4121, grad_fn=<NllLossBackward>)
# Error en la iteración: 119 tensor(1.4108, grad_fn=<NllLossBackward>)
# Error en la iteración: 120 tensor(1.4095, grad_fn=<NllLossBackward>)
# Error en la iteración: 121 tensor(1.4082, grad_fn=<NllLossBackward>)
# Error en la iteración: 122 tensor(1.4068, grad_fn=<NllLossBackward>)
# Error en la iteración: 123 tensor(1.4057, grad_fn=<NllLossBackward>)
# Error en la iteración: 124 tensor(1.4044, grad_fn=<NllLossBackward>)
# Error en la iteración: 125 tensor(1.4032, grad_fn=<NllLossBackward>)
# Error en la iteración: 126 tensor(1.4020, grad_fn=<NllLossBackward>)
# Error en la iteración: 127 tensor(1.4008, grad_fn=<NllLossBackward>)
# Error en la iteración: 128 tensor(1.3995, grad_fn=<NllLossBackward>)
# Error en la iteración: 129 tensor(1.3984, grad_fn=<NllLossBackward>)
# Error en la iteración: 130 tensor(1.3973, grad_fn=<NllLossBackward>)
# Error en la iteración: 131 tensor(1.3962, grad_fn=<NllLossBackward>)
# Error en la iteración: 132 tensor(1.3952, grad_fn=<NllLossBackward>)
# Error en la iteración: 133 tensor(1.3940, grad_fn=<NllLossBackward>)
# Error en la iteración: 134 tensor(1.3930, grad_fn=<NllLossBackward>)
# Error en la iteración: 135 tensor(1.3919, grad_fn=<NllLossBackward>)
# Error en la iteración: 136 tensor(1.3909, grad_fn=<NllLossBackward>)
# Error en la iteración: 137 tensor(1.3899, grad_fn=<NllLossBackward>)
# Error en la iteración: 138 tensor(1.3889, grad_fn=<NllLossBackward>)
# Error en la iteración: 139 tensor(1.3879, grad_fn=<NllLossBackward>)
# Error en la iteración: 140 tensor(1.3869, grad_fn=<NllLossBackward>)
# Error en la iteración: 141 tensor(1.3859, grad_fn=<NllLossBackward>)
# Error en la iteración: 142 tensor(1.3850, grad_fn=<NllLossBackward>)
# Error en la iteración: 143 tensor(1.3842, grad_fn=<NllLossBackward>)
# Error en la iteración: 144 tensor(1.3833, grad_fn=<NllLossBackward>)
# Error en la iteración: 145 tensor(1.3824, grad_fn=<NllLossBackward>)
# Error en la iteración: 146 tensor(1.3815, grad_fn=<NllLossBackward>)
# Error en la iteración: 147 tensor(1.3806, grad_fn=<NllLossBackward>)
# Error en la iteración: 148 tensor(1.3797, grad_fn=<NllLossBackward>)
# Error en la iteración: 149 tensor(1.3789, grad_fn=<NllLossBackward>)
# Error en la iteración: 150 tensor(1.3780, grad_fn=<NllLossBackward>)
# Error en la iteración: 151 tensor(1.3771, grad_fn=<NllLossBackward>)
# Error en la iteración: 152 tensor(1.3764, grad_fn=<NllLossBackward>)
# Error en la iteración: 153 tensor(1.3755, grad_fn=<NllLossBackward>)
# Error en la iteración: 154 tensor(1.3747, grad_fn=<NllLossBackward>)
# Error en la iteración: 155 tensor(1.3739, grad_fn=<NllLossBackward>)
# Error en la iteración: 156 tensor(1.3730, grad_fn=<NllLossBackward>)
# Error en la iteración: 157 tensor(1.3721, grad_fn=<NllLossBackward>)
# Error en la iteración: 158 tensor(1.3713, grad_fn=<NllLossBackward>)
# Error en la iteración: 159 tensor(1.3705, grad_fn=<NllLossBackward>)
# Error en la iteración: 160 tensor(1.3698, grad_fn=<NllLossBackward>)
# Error en la iteración: 161 tensor(1.3690, grad_fn=<NllLossBackward>)
# Error en la iteración: 162 tensor(1.3682, grad_fn=<NllLossBackward>)
# Error en la iteración: 163 tensor(1.3675, grad_fn=<NllLossBackward>)
# Error en la iteración: 164 tensor(1.3667, grad_fn=<NllLossBackward>)
# Error en la iteración: 165 tensor(1.3660, grad_fn=<NllLossBackward>)
# Error en la iteración: 166 tensor(1.3651, grad_fn=<NllLossBackward>)
# Error en la iteración: 167 tensor(1.3643, grad_fn=<NllLossBackward>)
# Error en la iteración: 168 tensor(1.3636, grad_fn=<NllLossBackward>)
# Error en la iteración: 169 tensor(1.3630, grad_fn=<NllLossBackward>)
# Error en la iteración: 170 tensor(1.3621, grad_fn=<NllLossBackward>)
# Error en la iteración: 171 tensor(1.3614, grad_fn=<NllLossBackward>)
# Error en la iteración: 172 tensor(1.3608, grad_fn=<NllLossBackward>)
# Error en la iteración: 173 tensor(1.3602, grad_fn=<NllLossBackward>)
# Error en la iteración: 174 tensor(1.3594, grad_fn=<NllLossBackward>)
# Error en la iteración: 175 tensor(1.3585, grad_fn=<NllLossBackward>)
# Error en la iteración: 176 tensor(1.3577, grad_fn=<NllLossBackward>)
# Error en la iteración: 177 tensor(1.3571, grad_fn=<NllLossBackward>)
# Error en la iteración: 178 tensor(1.3565, grad_fn=<NllLossBackward>)
# Error en la iteración: 179 tensor(1.3557, grad_fn=<NllLossBackward>)
# Error en la iteración: 180 tensor(1.3549, grad_fn=<NllLossBackward>)
# Error en la iteración: 181 tensor(1.3542, grad_fn=<NllLossBackward>)
# Error en la iteración: 182 tensor(1.3537, grad_fn=<NllLossBackward>)
# Error en la iteración: 183 tensor(1.3532, grad_fn=<NllLossBackward>)
# Error en la iteración: 184 tensor(1.3523, grad_fn=<NllLossBackward>)
# Error en la iteración: 185 tensor(1.3514, grad_fn=<NllLossBackward>)
# Error en la iteración: 186 tensor(1.3507, grad_fn=<NllLossBackward>)
# Error en la iteración: 187 tensor(1.3503, grad_fn=<NllLossBackward>)
# Error en la iteración: 188 tensor(1.3497, grad_fn=<NllLossBackward>)
# Error en la iteración: 189 tensor(1.3489, grad_fn=<NllLossBackward>)
# Error en la iteración: 190 tensor(1.3481, grad_fn=<NllLossBackward>)
# Error en la iteración: 191 tensor(1.3475, grad_fn=<NllLossBackward>)
# Error en la iteración: 192 tensor(1.3471, grad_fn=<NllLossBackward>)
# Error en la iteración: 193 tensor(1.3466, grad_fn=<NllLossBackward>)
# Error en la iteración: 194 tensor(1.3456, grad_fn=<NllLossBackward>)
# Error en la iteración: 195 tensor(1.3449, grad_fn=<NllLossBackward>)
# Error en la iteración: 196 tensor(1.3444, grad_fn=<NllLossBackward>)
# Error en la iteración: 197 tensor(1.3438, grad_fn=<NllLossBackward>)
# Error en la iteración: 198 tensor(1.3432, grad_fn=<NllLossBackward>)
# Error en la iteración: 199 tensor(1.3423, grad_fn=<NllLossBackward>)
# Error en la iteración: 200 tensor(1.3418, grad_fn=<NllLossBackward>)
# Error en la iteración: 201 tensor(1.3414, grad_fn=<NllLossBackward>)
# Error en la iteración: 202 tensor(1.3410, grad_fn=<NllLossBackward>)
# Error en la iteración: 203 tensor(1.3400, grad_fn=<NllLossBackward>)
# Error en la iteración: 204 tensor(1.3392, grad_fn=<NllLossBackward>)
# Error en la iteración: 205 tensor(1.3387, grad_fn=<NllLossBackward>)
# Error en la iteración: 206 tensor(1.3383, grad_fn=<NllLossBackward>)
# Error en la iteración: 207 tensor(1.3378, grad_fn=<NllLossBackward>)
# Error en la iteración: 208 tensor(1.3372, grad_fn=<NllLossBackward>)
# Error en la iteración: 209 tensor(1.3365, grad_fn=<NllLossBackward>)
# Error en la iteración: 210 tensor(1.3358, grad_fn=<NllLossBackward>)
# Error en la iteración: 211 tensor(1.3352, grad_fn=<NllLossBackward>)
# Error en la iteración: 212 tensor(1.3347, grad_fn=<NllLossBackward>)
# Error en la iteración: 213 tensor(1.3343, grad_fn=<NllLossBackward>)
# Error en la iteración: 214 tensor(1.3336, grad_fn=<NllLossBackward>)
# Error en la iteración: 215 tensor(1.3328, grad_fn=<NllLossBackward>)
# Error en la iteración: 216 tensor(1.3323, grad_fn=<NllLossBackward>)
# Error en la iteración: 217 tensor(1.3318, grad_fn=<NllLossBackward>)
# Error en la iteración: 218 tensor(1.3314, grad_fn=<NllLossBackward>)
# Error en la iteración: 219 tensor(1.3308, grad_fn=<NllLossBackward>)
# Error en la iteración: 220 tensor(1.3302, grad_fn=<NllLossBackward>)
# Error en la iteración: 221 tensor(1.3295, grad_fn=<NllLossBackward>)
# Error en la iteración: 222 tensor(1.3288, grad_fn=<NllLossBackward>)
# Error en la iteración: 223 tensor(1.3285, grad_fn=<NllLossBackward>)
# Error en la iteración: 224 tensor(1.3282, grad_fn=<NllLossBackward>)
# Error en la iteración: 225 tensor(1.3279, grad_fn=<NllLossBackward>)
# Error en la iteración: 226 tensor(1.3274, grad_fn=<NllLossBackward>)
# Error en la iteración: 227 tensor(1.3266, grad_fn=<NllLossBackward>)
# Error en la iteración: 228 tensor(1.3257, grad_fn=<NllLossBackward>)
# Error en la iteración: 229 tensor(1.3251, grad_fn=<NllLossBackward>)
# Error en la iteración: 230 tensor(1.3248, grad_fn=<NllLossBackward>)
# Error en la iteración: 231 tensor(1.3247, grad_fn=<NllLossBackward>)
# Error en la iteración: 232 tensor(1.3243, grad_fn=<NllLossBackward>)
# Error en la iteración: 233 tensor(1.3237, grad_fn=<NllLossBackward>)
# Error en la iteración: 234 tensor(1.3228, grad_fn=<NllLossBackward>)
# Error en la iteración: 235 tensor(1.3222, grad_fn=<NllLossBackward>)
# Error en la iteración: 236 tensor(1.3216, grad_fn=<NllLossBackward>)
# Error en la iteración: 237 tensor(1.3212, grad_fn=<NllLossBackward>)
# Error en la iteración: 238 tensor(1.3210, grad_fn=<NllLossBackward>)
# Error en la iteración: 239 tensor(1.3206, grad_fn=<NllLossBackward>)
# Error en la iteración: 240 tensor(1.3199, grad_fn=<NllLossBackward>)
# Error en la iteración: 241 tensor(1.3191, grad_fn=<NllLossBackward>)
# Error en la iteración: 242 tensor(1.3184, grad_fn=<NllLossBackward>)
# Error en la iteración: 243 tensor(1.3180, grad_fn=<NllLossBackward>)
# Error en la iteración: 244 tensor(1.3177, grad_fn=<NllLossBackward>)
# Error en la iteración: 245 tensor(1.3177, grad_fn=<NllLossBackward>)
# Error en la iteración: 246 tensor(1.3172, grad_fn=<NllLossBackward>)
# Error en la iteración: 247 tensor(1.3161, grad_fn=<NllLossBackward>)
# Error en la iteración: 248 tensor(1.3152, grad_fn=<NllLossBackward>)
# Error en la iteración: 249 tensor(1.3147, grad_fn=<NllLossBackward>)
# Error en la iteración: 250 tensor(1.3143, grad_fn=<NllLossBackward>)
# Error en la iteración: 251 tensor(1.3141, grad_fn=<NllLossBackward>)
# Error en la iteración: 252 tensor(1.3139, grad_fn=<NllLossBackward>)
# Error en la iteración: 253 tensor(1.3134, grad_fn=<NllLossBackward>)
# Error en la iteración: 254 tensor(1.3125, grad_fn=<NllLossBackward>)
# Error en la iteración: 255 tensor(1.3117, grad_fn=<NllLossBackward>)
# Error en la iteración: 256 tensor(1.3111, grad_fn=<NllLossBackward>)
# Error en la iteración: 257 tensor(1.3107, grad_fn=<NllLossBackward>)
# Error en la iteración: 258 tensor(1.3105, grad_fn=<NllLossBackward>)
# Error en la iteración: 259 tensor(1.3104, grad_fn=<NllLossBackward>)
# Error en la iteración: 260 tensor(1.3100, grad_fn=<NllLossBackward>)
# Error en la iteración: 261 tensor(1.3090, grad_fn=<NllLossBackward>)
# Error en la iteración: 262 tensor(1.3082, grad_fn=<NllLossBackward>)
# Error en la iteración: 263 tensor(1.3076, grad_fn=<NllLossBackward>)
# Error en la iteración: 264 tensor(1.3073, grad_fn=<NllLossBackward>)
# Error en la iteración: 265 tensor(1.3071, grad_fn=<NllLossBackward>)
# Error en la iteración: 266 tensor(1.3071, grad_fn=<NllLossBackward>)
# Error en la iteración: 267 tensor(1.3065, grad_fn=<NllLossBackward>)
# Error en la iteración: 268 tensor(1.3056, grad_fn=<NllLossBackward>)
# Error en la iteración: 269 tensor(1.3046, grad_fn=<NllLossBackward>)
# Error en la iteración: 270 tensor(1.3041, grad_fn=<NllLossBackward>)
# Error en la iteración: 271 tensor(1.3037, grad_fn=<NllLossBackward>)
# Error en la iteración: 272 tensor(1.3037, grad_fn=<NllLossBackward>)
# Error en la iteración: 273 tensor(1.3037, grad_fn=<NllLossBackward>)
# Error en la iteración: 274 tensor(1.3029, grad_fn=<NllLossBackward>)
# Error en la iteración: 275 tensor(1.3019, grad_fn=<NllLossBackward>)
# Error en la iteración: 276 tensor(1.3013, grad_fn=<NllLossBackward>)
# Error en la iteración: 277 tensor(1.3007, grad_fn=<NllLossBackward>)
# Error en la iteración: 278 tensor(1.3004, grad_fn=<NllLossBackward>)
# Error en la iteración: 279 tensor(1.3002, grad_fn=<NllLossBackward>)
# Error en la iteración: 280 tensor(1.3001, grad_fn=<NllLossBackward>)
# Error en la iteración: 281 tensor(1.2994, grad_fn=<NllLossBackward>)
# Error en la iteración: 282 tensor(1.2982, grad_fn=<NllLossBackward>)
# Error en la iteración: 283 tensor(1.2976, grad_fn=<NllLossBackward>)
# Error en la iteración: 284 tensor(1.2973, grad_fn=<NllLossBackward>)
# Error en la iteración: 285 tensor(1.2971, grad_fn=<NllLossBackward>)
# Error en la iteración: 286 tensor(1.2971, grad_fn=<NllLossBackward>)
# Error en la iteración: 287 tensor(1.2965, grad_fn=<NllLossBackward>)
# Error en la iteración: 288 tensor(1.2956, grad_fn=<NllLossBackward>)
# Error en la iteración: 289 tensor(1.2949, grad_fn=<NllLossBackward>)
# Error en la iteración: 290 tensor(1.2944, grad_fn=<NllLossBackward>)
# Error en la iteración: 291 tensor(1.2941, grad_fn=<NllLossBackward>)
# Error en la iteración: 292 tensor(1.2938, grad_fn=<NllLossBackward>)
# Error en la iteración: 293 tensor(1.2935, grad_fn=<NllLossBackward>)
# Error en la iteración: 294 tensor(1.2930, grad_fn=<NllLossBackward>)
# Error en la iteración: 295 tensor(1.2922, grad_fn=<NllLossBackward>)
# Error en la iteración: 296 tensor(1.2913, grad_fn=<NllLossBackward>)
# Error en la iteración: 297 tensor(1.2908, grad_fn=<NllLossBackward>)
# Error en la iteración: 298 tensor(1.2904, grad_fn=<NllLossBackward>)
# Error en la iteración: 299 tensor(1.2902, grad_fn=<NllLossBackward>)
# Error en la iteración: 300 tensor(1.2901, grad_fn=<NllLossBackward>)
# Error en la iteración: 301 tensor(1.2900, grad_fn=<NllLossBackward>)
# Error en la iteración: 302 tensor(1.2895, grad_fn=<NllLossBackward>)
# Error en la iteración: 303 tensor(1.2884, grad_fn=<NllLossBackward>)
# Error en la iteración: 304 tensor(1.2876, grad_fn=<NllLossBackward>)
# Error en la iteración: 305 tensor(1.2870, grad_fn=<NllLossBackward>)
# Error en la iteración: 306 tensor(1.2866, grad_fn=<NllLossBackward>)
# Error en la iteración: 307 tensor(1.2865, grad_fn=<NllLossBackward>)
# Error en la iteración: 308 tensor(1.2863, grad_fn=<NllLossBackward>)
# Error en la iteración: 309 tensor(1.2857, grad_fn=<NllLossBackward>)
# Error en la iteración: 310 tensor(1.2848, grad_fn=<NllLossBackward>)
# Error en la iteración: 311 tensor(1.2841, grad_fn=<NllLossBackward>)
# Error en la iteración: 312 tensor(1.2839, grad_fn=<NllLossBackward>)
# Error en la iteración: 313 tensor(1.2836, grad_fn=<NllLossBackward>)
# Error en la iteración: 314 tensor(1.2834, grad_fn=<NllLossBackward>)
# Error en la iteración: 315 tensor(1.2834, grad_fn=<NllLossBackward>)
# Error en la iteración: 316 tensor(1.2828, grad_fn=<NllLossBackward>)
# Error en la iteración: 317 tensor(1.2818, grad_fn=<NllLossBackward>)
# Error en la iteración: 318 tensor(1.2809, grad_fn=<NllLossBackward>)
# Error en la iteración: 319 tensor(1.2803, grad_fn=<NllLossBackward>)
# Error en la iteración: 320 tensor(1.2799, grad_fn=<NllLossBackward>)
# Error en la iteración: 321 tensor(1.2796, grad_fn=<NllLossBackward>)
# Error en la iteración: 322 tensor(1.2797, grad_fn=<NllLossBackward>)
# Error en la iteración: 323 tensor(1.2792, grad_fn=<NllLossBackward>)
# Error en la iteración: 324 tensor(1.2782, grad_fn=<NllLossBackward>)
# Error en la iteración: 325 tensor(1.2777, grad_fn=<NllLossBackward>)
# Error en la iteración: 326 tensor(1.2773, grad_fn=<NllLossBackward>)
# Error en la iteración: 327 tensor(1.2770, grad_fn=<NllLossBackward>)
# Error en la iteración: 328 tensor(1.2768, grad_fn=<NllLossBackward>)
# Error en la iteración: 329 tensor(1.2770, grad_fn=<NllLossBackward>)
# Error en la iteración: 330 tensor(1.2765, grad_fn=<NllLossBackward>)
# Error en la iteración: 331 tensor(1.2752, grad_fn=<NllLossBackward>)
# Error en la iteración: 332 tensor(1.2743, grad_fn=<NllLossBackward>)
# Error en la iteración: 333 tensor(1.2738, grad_fn=<NllLossBackward>)
# Error en la iteración: 334 tensor(1.2734, grad_fn=<NllLossBackward>)
# Error en la iteración: 335 tensor(1.2733, grad_fn=<NllLossBackward>)
# Error en la iteración: 336 tensor(1.2735, grad_fn=<NllLossBackward>)
# Error en la iteración: 337 tensor(1.2729, grad_fn=<NllLossBackward>)
# Error en la iteración: 338 tensor(1.2717, grad_fn=<NllLossBackward>)
# Error en la iteración: 339 tensor(1.2710, grad_fn=<NllLossBackward>)
# Error en la iteración: 340 tensor(1.2709, grad_fn=<NllLossBackward>)
# Error en la iteración: 341 tensor(1.2711, grad_fn=<NllLossBackward>)
# Error en la iteración: 342 tensor(1.2711, grad_fn=<NllLossBackward>)
# Error en la iteración: 343 tensor(1.2703, grad_fn=<NllLossBackward>)
# Error en la iteración: 344 tensor(1.2694, grad_fn=<NllLossBackward>)
# Error en la iteración: 345 tensor(1.2686, grad_fn=<NllLossBackward>)
# Error en la iteración: 346 tensor(1.2681, grad_fn=<NllLossBackward>)
# Error en la iteración: 347 tensor(1.2675, grad_fn=<NllLossBackward>)
# Error en la iteración: 348 tensor(1.2674, grad_fn=<NllLossBackward>)
# Error en la iteración: 349 tensor(1.2674, grad_fn=<NllLossBackward>)
# Error en la iteración: 350 tensor(1.2672, grad_fn=<NllLossBackward>)
# Error en la iteración: 351 tensor(1.2663, grad_fn=<NllLossBackward>)
# Error en la iteración: 352 tensor(1.2652, grad_fn=<NllLossBackward>)
# Error en la iteración: 353 tensor(1.2646, grad_fn=<NllLossBackward>)
# Error en la iteración: 354 tensor(1.2643, grad_fn=<NllLossBackward>)
# Error en la iteración: 355 tensor(1.2643, grad_fn=<NllLossBackward>)
# Error en la iteración: 356 tensor(1.2645, grad_fn=<NllLossBackward>)
# Error en la iteración: 357 tensor(1.2643, grad_fn=<NllLossBackward>)
# Error en la iteración: 358 tensor(1.2635, grad_fn=<NllLossBackward>)
# Error en la iteración: 359 tensor(1.2628, grad_fn=<NllLossBackward>)
# Error en la iteración: 360 tensor(1.2621, grad_fn=<NllLossBackward>)
# Error en la iteración: 361 tensor(1.2616, grad_fn=<NllLossBackward>)
# Error en la iteración: 362 tensor(1.2617, grad_fn=<NllLossBackward>)
# Error en la iteración: 363 tensor(1.2618, grad_fn=<NllLossBackward>)
# Error en la iteración: 364 tensor(1.2612, grad_fn=<NllLossBackward>)
# Error en la iteración: 365 tensor(1.2601, grad_fn=<NllLossBackward>)
# Error en la iteración: 366 tensor(1.2591, grad_fn=<NllLossBackward>)
# Error en la iteración: 367 tensor(1.2586, grad_fn=<NllLossBackward>)
# Error en la iteración: 368 tensor(1.2584, grad_fn=<NllLossBackward>)
# Error en la iteración: 369 tensor(1.2584, grad_fn=<NllLossBackward>)
# Error en la iteración: 370 tensor(1.2583, grad_fn=<NllLossBackward>)
# Error en la iteración: 371 tensor(1.2578, grad_fn=<NllLossBackward>)
# Error en la iteración: 372 tensor(1.2568, grad_fn=<NllLossBackward>)
# Error en la iteración: 373 tensor(1.2562, grad_fn=<NllLossBackward>)
# Error en la iteración: 374 tensor(1.2559, grad_fn=<NllLossBackward>)
# Error en la iteración: 375 tensor(1.2559, grad_fn=<NllLossBackward>)
# Error en la iteración: 376 tensor(1.2559, grad_fn=<NllLossBackward>)
# Error en la iteración: 377 tensor(1.2558, grad_fn=<NllLossBackward>)
# Error en la iteración: 378 tensor(1.2553, grad_fn=<NllLossBackward>)
# Error en la iteración: 379 tensor(1.2546, grad_fn=<NllLossBackward>)
# Error en la iteración: 380 tensor(1.2539, grad_fn=<NllLossBackward>)
# Error en la iteración: 381 tensor(1.2532, grad_fn=<NllLossBackward>)
# Error en la iteración: 382 tensor(1.2527, grad_fn=<NllLossBackward>)
# Error en la iteración: 383 tensor(1.2523, grad_fn=<NllLossBackward>)
# Error en la iteración: 384 tensor(1.2523, grad_fn=<NllLossBackward>)
# Error en la iteración: 385 tensor(1.2525, grad_fn=<NllLossBackward>)
# Error en la iteración: 386 tensor(1.2520, grad_fn=<NllLossBackward>)
# Error en la iteración: 387 tensor(1.2508, grad_fn=<NllLossBackward>)
# Error en la iteración: 388 tensor(1.2498, grad_fn=<NllLossBackward>)
# Error en la iteración: 389 tensor(1.2494, grad_fn=<NllLossBackward>)
# Error en la iteración: 390 tensor(1.2494, grad_fn=<NllLossBackward>)
# Error en la iteración: 391 tensor(1.2496, grad_fn=<NllLossBackward>)
# Error en la iteración: 392 tensor(1.2495, grad_fn=<NllLossBackward>)
# Error en la iteración: 393 tensor(1.2489, grad_fn=<NllLossBackward>)
# Error en la iteración: 394 tensor(1.2482, grad_fn=<NllLossBackward>)
# Error en la iteración: 395 tensor(1.2476, grad_fn=<NllLossBackward>)
# Error en la iteración: 396 tensor(1.2473, grad_fn=<NllLossBackward>)
# Error en la iteración: 397 tensor(1.2470, grad_fn=<NllLossBackward>)
# Error en la iteración: 398 tensor(1.2468, grad_fn=<NllLossBackward>)
# Error en la iteración: 399 tensor(1.2468, grad_fn=<NllLossBackward>)
# Error en la iteración: 400 tensor(1.2468, grad_fn=<NllLossBackward>)
# Error en la iteración: 401 tensor(1.2459, grad_fn=<NllLossBackward>)
# Error en la iteración: 402 tensor(1.2446, grad_fn=<NllLossBackward>)
# Error en la iteración: 403 tensor(1.2442, grad_fn=<NllLossBackward>)
# Error en la iteración: 404 tensor(1.2440, grad_fn=<NllLossBackward>)
# Error en la iteración: 405 tensor(1.2438, grad_fn=<NllLossBackward>)
# Error en la iteración: 406 tensor(1.2437, grad_fn=<NllLossBackward>)
# Error en la iteración: 407 tensor(1.2434, grad_fn=<NllLossBackward>)
# Error en la iteración: 408 tensor(1.2425, grad_fn=<NllLossBackward>)
# Error en la iteración: 409 tensor(1.2416, grad_fn=<NllLossBackward>)
# Error en la iteración: 410 tensor(1.2411, grad_fn=<NllLossBackward>)
# Error en la iteración: 411 tensor(1.2410, grad_fn=<NllLossBackward>)
# Error en la iteración: 412 tensor(1.2412, grad_fn=<NllLossBackward>)
# Error en la iteración: 413 tensor(1.2415, grad_fn=<NllLossBackward>)
# Error en la iteración: 414 tensor(1.2410, grad_fn=<NllLossBackward>)
# Error en la iteración: 415 tensor(1.2399, grad_fn=<NllLossBackward>)
# Error en la iteración: 416 tensor(1.2394, grad_fn=<NllLossBackward>)
# Error en la iteración: 417 tensor(1.2394, grad_fn=<NllLossBackward>)
# Error en la iteración: 418 tensor(1.2394, grad_fn=<NllLossBackward>)
# Error en la iteración: 419 tensor(1.2392, grad_fn=<NllLossBackward>)
# Error en la iteración: 420 tensor(1.2388, grad_fn=<NllLossBackward>)
# Error en la iteración: 421 tensor(1.2383, grad_fn=<NllLossBackward>)
# Error en la iteración: 422 tensor(1.2378, grad_fn=<NllLossBackward>)
# Error en la iteración: 423 tensor(1.2368, grad_fn=<NllLossBackward>)
# Error en la iteración: 424 tensor(1.2361, grad_fn=<NllLossBackward>)
# Error en la iteración: 425 tensor(1.2355, grad_fn=<NllLossBackward>)
# Error en la iteración: 426 tensor(1.2357, grad_fn=<NllLossBackward>)
# Error en la iteración: 427 tensor(1.2360, grad_fn=<NllLossBackward>)
# Error en la iteración: 428 tensor(1.2356, grad_fn=<NllLossBackward>)
# Error en la iteración: 429 tensor(1.2344, grad_fn=<NllLossBackward>)
# Error en la iteración: 430 tensor(1.2335, grad_fn=<NllLossBackward>)
# Error en la iteración: 431 tensor(1.2333, grad_fn=<NllLossBackward>)
# Error en la iteración: 432 tensor(1.2330, grad_fn=<NllLossBackward>)
# Error en la iteración: 433 tensor(1.2332, grad_fn=<NllLossBackward>)
# Error en la iteración: 434 tensor(1.2331, grad_fn=<NllLossBackward>)
# Error en la iteración: 435 tensor(1.2327, grad_fn=<NllLossBackward>)
# Error en la iteración: 436 tensor(1.2320, grad_fn=<NllLossBackward>)
# Error en la iteración: 437 tensor(1.2315, grad_fn=<NllLossBackward>)
# Error en la iteración: 438 tensor(1.2315, grad_fn=<NllLossBackward>)
# Error en la iteración: 439 tensor(1.2312, grad_fn=<NllLossBackward>)
# Error en la iteración: 440 tensor(1.2312, grad_fn=<NllLossBackward>)
# Error en la iteración: 441 tensor(1.2312, grad_fn=<NllLossBackward>)
# Error en la iteración: 442 tensor(1.2312, grad_fn=<NllLossBackward>)
# Error en la iteración: 443 tensor(1.2306, grad_fn=<NllLossBackward>)
# Error en la iteración: 444 tensor(1.2295, grad_fn=<NllLossBackward>)
# Error en la iteración: 445 tensor(1.2288, grad_fn=<NllLossBackward>)
# Error en la iteración: 446 tensor(1.2282, grad_fn=<NllLossBackward>)
# Error en la iteración: 447 tensor(1.2278, grad_fn=<NllLossBackward>)
# Error en la iteración: 448 tensor(1.2280, grad_fn=<NllLossBackward>)
# Error en la iteración: 449 tensor(1.2279, grad_fn=<NllLossBackward>)
# Error en la iteración: 450 tensor(1.2268, grad_fn=<NllLossBackward>)
# Error en la iteración: 451 tensor(1.2258, grad_fn=<NllLossBackward>)
# Error en la iteración: 452 tensor(1.2253, grad_fn=<NllLossBackward>)
# Error en la iteración: 453 tensor(1.2251, grad_fn=<NllLossBackward>)
# Error en la iteración: 454 tensor(1.2253, grad_fn=<NllLossBackward>)
# Error en la iteración: 455 tensor(1.2255, grad_fn=<NllLossBackward>)
# Error en la iteración: 456 tensor(1.2253, grad_fn=<NllLossBackward>)
# Error en la iteración: 457 tensor(1.2244, grad_fn=<NllLossBackward>)
# Error en la iteración: 458 tensor(1.2237, grad_fn=<NllLossBackward>)
# Error en la iteración: 459 tensor(1.2236, grad_fn=<NllLossBackward>)
# Error en la iteración: 460 tensor(1.2233, grad_fn=<NllLossBackward>)
# Error en la iteración: 461 tensor(1.2233, grad_fn=<NllLossBackward>)
# Error en la iteración: 462 tensor(1.2237, grad_fn=<NllLossBackward>)
# Error en la iteración: 463 tensor(1.2238, grad_fn=<NllLossBackward>)
# Error en la iteración: 464 tensor(1.2231, grad_fn=<NllLossBackward>)
# Error en la iteración: 465 tensor(1.2217, grad_fn=<NllLossBackward>)
# Error en la iteración: 466 tensor(1.2210, grad_fn=<NllLossBackward>)
# Error en la iteración: 467 tensor(1.2209, grad_fn=<NllLossBackward>)
# Error en la iteración: 468 tensor(1.2210, grad_fn=<NllLossBackward>)
# Error en la iteración: 469 tensor(1.2207, grad_fn=<NllLossBackward>)
# Error en la iteración: 470 tensor(1.2200, grad_fn=<NllLossBackward>)
# Error en la iteración: 471 tensor(1.2190, grad_fn=<NllLossBackward>)
# Error en la iteración: 472 tensor(1.2185, grad_fn=<NllLossBackward>)
# Error en la iteración: 473 tensor(1.2181, grad_fn=<NllLossBackward>)
# Error en la iteración: 474 tensor(1.2178, grad_fn=<NllLossBackward>)
# Error en la iteración: 475 tensor(1.2178, grad_fn=<NllLossBackward>)
# Error en la iteración: 476 tensor(1.2178, grad_fn=<NllLossBackward>)
# Error en la iteración: 477 tensor(1.2176, grad_fn=<NllLossBackward>)
# Error en la iteración: 478 tensor(1.2167, grad_fn=<NllLossBackward>)
# Error en la iteración: 479 tensor(1.2160, grad_fn=<NllLossBackward>)
# Error en la iteración: 480 tensor(1.2156, grad_fn=<NllLossBackward>)
# Error en la iteración: 481 tensor(1.2154, grad_fn=<NllLossBackward>)
# Error en la iteración: 482 tensor(1.2158, grad_fn=<NllLossBackward>)
# Error en la iteración: 483 tensor(1.2163, grad_fn=<NllLossBackward>)
# Error en la iteración: 484 tensor(1.2159, grad_fn=<NllLossBackward>)
# Error en la iteración: 485 tensor(1.2150, grad_fn=<NllLossBackward>)
# Error en la iteración: 486 tensor(1.2145, grad_fn=<NllLossBackward>)
# Error en la iteración: 487 tensor(1.2144, grad_fn=<NllLossBackward>)
# Error en la iteración: 488 tensor(1.2142, grad_fn=<NllLossBackward>)
# Error en la iteración: 489 tensor(1.2137, grad_fn=<NllLossBackward>)
# Error en la iteración: 490 tensor(1.2135, grad_fn=<NllLossBackward>)
# Error en la iteración: 491 tensor(1.2131, grad_fn=<NllLossBackward>)
# Error en la iteración: 492 tensor(1.2125, grad_fn=<NllLossBackward>)
# Error en la iteración: 493 tensor(1.2116, grad_fn=<NllLossBackward>)
# Error en la iteración: 494 tensor(1.2107, grad_fn=<NllLossBackward>)
# Error en la iteración: 495 tensor(1.2102, grad_fn=<NllLossBackward>)
# Error en la iteración: 496 tensor(1.2103, grad_fn=<NllLossBackward>)
# Error en la iteración: 497 tensor(1.2108, grad_fn=<NllLossBackward>)
# Error en la iteración: 498 tensor(1.2107, grad_fn=<NllLossBackward>)
# Error en la iteración: 499 tensor(1.2099, grad_fn=<NllLossBackward>)
# Error en la iteración: 500 tensor(1.2089, grad_fn=<NllLossBackward>)
# Error en la iteración: 501 tensor(1.2085, grad_fn=<NllLossBackward>)
# Error en la iteración: 502 tensor(1.2082, grad_fn=<NllLossBackward>)
# Error en la iteración: 503 tensor(1.2078, grad_fn=<NllLossBackward>)
# Error en la iteración: 504 tensor(1.2076, grad_fn=<NllLossBackward>)
# Error en la iteración: 505 tensor(1.2079, grad_fn=<NllLossBackward>)
# Error en la iteración: 506 tensor(1.2083, grad_fn=<NllLossBackward>)
# Error en la iteración: 507 tensor(1.2079, grad_fn=<NllLossBackward>)
# Error en la iteración: 508 tensor(1.2069, grad_fn=<NllLossBackward>)
# Error en la iteración: 509 tensor(1.2063, grad_fn=<NllLossBackward>)
# Error en la iteración: 510 tensor(1.2062, grad_fn=<NllLossBackward>)
# Error en la iteración: 511 tensor(1.2062, grad_fn=<NllLossBackward>)
# Error en la iteración: 512 tensor(1.2063, grad_fn=<NllLossBackward>)
# Error en la iteración: 513 tensor(1.2063, grad_fn=<NllLossBackward>)
# Error en la iteración: 514 tensor(1.2058, grad_fn=<NllLossBackward>)
# Error en la iteración: 515 tensor(1.2047, grad_fn=<NllLossBackward>)
# Error en la iteración: 516 tensor(1.2040, grad_fn=<NllLossBackward>)
# Error en la iteración: 517 tensor(1.2034, grad_fn=<NllLossBackward>)
# Error en la iteración: 518 tensor(1.2032, grad_fn=<NllLossBackward>)
# Error en la iteración: 519 tensor(1.2032, grad_fn=<NllLossBackward>)
# Error en la iteración: 520 tensor(1.2030, grad_fn=<NllLossBackward>)
# Error en la iteración: 521 tensor(1.2024, grad_fn=<NllLossBackward>)
# Error en la iteración: 522 tensor(1.2013, grad_fn=<NllLossBackward>)
# Error en la iteración: 523 tensor(1.2006, grad_fn=<NllLossBackward>)
# Error en la iteración: 524 tensor(1.2003, grad_fn=<NllLossBackward>)
# Error en la iteración: 525 tensor(1.2002, grad_fn=<NllLossBackward>)
# Error en la iteración: 526 tensor(1.2005, grad_fn=<NllLossBackward>)
# Error en la iteración: 527 tensor(1.2007, grad_fn=<NllLossBackward>)
# Error en la iteración: 528 tensor(1.2003, grad_fn=<NllLossBackward>)
# Error en la iteración: 529 tensor(1.1993, grad_fn=<NllLossBackward>)
# Error en la iteración: 530 tensor(1.1984, grad_fn=<NllLossBackward>)
# Error en la iteración: 531 tensor(1.1984, grad_fn=<NllLossBackward>)
# Error en la iteración: 532 tensor(1.1984, grad_fn=<NllLossBackward>)
# Error en la iteración: 533 tensor(1.1982, grad_fn=<NllLossBackward>)
# Error en la iteración: 534 tensor(1.1983, grad_fn=<NllLossBackward>)
# Error en la iteración: 535 tensor(1.1985, grad_fn=<NllLossBackward>)
# Error en la iteración: 536 tensor(1.1984, grad_fn=<NllLossBackward>)
# Error en la iteración: 537 tensor(1.1977, grad_fn=<NllLossBackward>)
# Error en la iteración: 538 tensor(1.1972, grad_fn=<NllLossBackward>)
# Error en la iteración: 539 tensor(1.1968, grad_fn=<NllLossBackward>)
# Error en la iteración: 540 tensor(1.1964, grad_fn=<NllLossBackward>)
# Error en la iteración: 541 tensor(1.1963, grad_fn=<NllLossBackward>)
# Error en la iteración: 542 tensor(1.1966, grad_fn=<NllLossBackward>)
# Error en la iteración: 543 tensor(1.1962, grad_fn=<NllLossBackward>)
# Error en la iteración: 544 tensor(1.1949, grad_fn=<NllLossBackward>)
# Error en la iteración: 545 tensor(1.1941, grad_fn=<NllLossBackward>)
# Error en la iteración: 546 tensor(1.1935, grad_fn=<NllLossBackward>)
# Error en la iteración: 547 tensor(1.1932, grad_fn=<NllLossBackward>)
# Error en la iteración: 548 tensor(1.1933, grad_fn=<NllLossBackward>)
# Error en la iteración: 549 tensor(1.1934, grad_fn=<NllLossBackward>)
# Error en la iteración: 550 tensor(1.1932, grad_fn=<NllLossBackward>)
# Error en la iteración: 551 tensor(1.1923, grad_fn=<NllLossBackward>)
# Error en la iteración: 552 tensor(1.1915, grad_fn=<NllLossBackward>)
# Error en la iteración: 553 tensor(1.1911, grad_fn=<NllLossBackward>)
# Error en la iteración: 554 tensor(1.1908, grad_fn=<NllLossBackward>)
# Error en la iteración: 555 tensor(1.1905, grad_fn=<NllLossBackward>)
# Error en la iteración: 556 tensor(1.1903, grad_fn=<NllLossBackward>)
# Error en la iteración: 557 tensor(1.1907, grad_fn=<NllLossBackward>)
# Error en la iteración: 558 tensor(1.1907, grad_fn=<NllLossBackward>)
# Error en la iteración: 559 tensor(1.1900, grad_fn=<NllLossBackward>)
# Error en la iteración: 560 tensor(1.1892, grad_fn=<NllLossBackward>)
# Error en la iteración: 561 tensor(1.1888, grad_fn=<NllLossBackward>)
# Error en la iteración: 562 tensor(1.1885, grad_fn=<NllLossBackward>)
# Error en la iteración: 563 tensor(1.1883, grad_fn=<NllLossBackward>)
# Error en la iteración: 564 tensor(1.1883, grad_fn=<NllLossBackward>)
# Error en la iteración: 565 tensor(1.1888, grad_fn=<NllLossBackward>)
# Error en la iteración: 566 tensor(1.1891, grad_fn=<NllLossBackward>)
# Error en la iteración: 567 tensor(1.1884, grad_fn=<NllLossBackward>)
# Error en la iteración: 568 tensor(1.1873, grad_fn=<NllLossBackward>)
# Error en la iteración: 569 tensor(1.1868, grad_fn=<NllLossBackward>)
# Error en la iteración: 570 tensor(1.1867, grad_fn=<NllLossBackward>)
# Error en la iteración: 571 tensor(1.1866, grad_fn=<NllLossBackward>)
# Error en la iteración: 572 tensor(1.1867, grad_fn=<NllLossBackward>)
# Error en la iteración: 573 tensor(1.1867, grad_fn=<NllLossBackward>)
# Error en la iteración: 574 tensor(1.1862, grad_fn=<NllLossBackward>)
# Error en la iteración: 575 tensor(1.1851, grad_fn=<NllLossBackward>)
# Error en la iteración: 576 tensor(1.1845, grad_fn=<NllLossBackward>)
# Error en la iteración: 577 tensor(1.1842, grad_fn=<NllLossBackward>)
# Error en la iteración: 578 tensor(1.1839, grad_fn=<NllLossBackward>)
# Error en la iteración: 579 tensor(1.1833, grad_fn=<NllLossBackward>)
# Error en la iteración: 580 tensor(1.1831, grad_fn=<NllLossBackward>)
# Error en la iteración: 581 tensor(1.1831, grad_fn=<NllLossBackward>)
# Error en la iteración: 582 tensor(1.1834, grad_fn=<NllLossBackward>)
# Error en la iteración: 583 tensor(1.1828, grad_fn=<NllLossBackward>)
# Error en la iteración: 584 tensor(1.1818, grad_fn=<NllLossBackward>)
# Error en la iteración: 585 tensor(1.1810, grad_fn=<NllLossBackward>)
# Error en la iteración: 586 tensor(1.1807, grad_fn=<NllLossBackward>)
# Error en la iteración: 587 tensor(1.1806, grad_fn=<NllLossBackward>)
# Error en la iteración: 588 tensor(1.1807, grad_fn=<NllLossBackward>)
# Error en la iteración: 589 tensor(1.1808, grad_fn=<NllLossBackward>)
# Error en la iteración: 590 tensor(1.1806, grad_fn=<NllLossBackward>)
# Error en la iteración: 591 tensor(1.1803, grad_fn=<NllLossBackward>)
# Error en la iteración: 592 tensor(1.1799, grad_fn=<NllLossBackward>)
# Error en la iteración: 593 tensor(1.1792, grad_fn=<NllLossBackward>)
# Error en la iteración: 594 tensor(1.1788, grad_fn=<NllLossBackward>)
# Error en la iteración: 595 tensor(1.1787, grad_fn=<NllLossBackward>)
# Error en la iteración: 596 tensor(1.1784, grad_fn=<NllLossBackward>)
# Error en la iteración: 597 tensor(1.1782, grad_fn=<NllLossBackward>)
# Error en la iteración: 598 tensor(1.1780, grad_fn=<NllLossBackward>)
# Error en la iteración: 599 tensor(1.1782, grad_fn=<NllLossBackward>)
# Error en la iteración: 600 tensor(1.1784, grad_fn=<NllLossBackward>)
# Error en la iteración: 601 tensor(1.1781, grad_fn=<NllLossBackward>)
# Error en la iteración: 602 tensor(1.1773, grad_fn=<NllLossBackward>)
# Error en la iteración: 603 tensor(1.1761, grad_fn=<NllLossBackward>)
# Error en la iteración: 604 tensor(1.1757, grad_fn=<NllLossBackward>)
# Error en la iteración: 605 tensor(1.1755, grad_fn=<NllLossBackward>)
# Error en la iteración: 606 tensor(1.1756, grad_fn=<NllLossBackward>)
# Error en la iteración: 607 tensor(1.1761, grad_fn=<NllLossBackward>)
# Error en la iteración: 608 tensor(1.1762, grad_fn=<NllLossBackward>)
# Error en la iteración: 609 tensor(1.1755, grad_fn=<NllLossBackward>)
# Error en la iteración: 610 tensor(1.1742, grad_fn=<NllLossBackward>)
# Error en la iteración: 611 tensor(1.1736, grad_fn=<NllLossBackward>)
# Error en la iteración: 612 tensor(1.1737, grad_fn=<NllLossBackward>)
# Error en la iteración: 613 tensor(1.1737, grad_fn=<NllLossBackward>)
# Error en la iteración: 614 tensor(1.1736, grad_fn=<NllLossBackward>)
# Error en la iteración: 615 tensor(1.1736, grad_fn=<NllLossBackward>)
# Error en la iteración: 616 tensor(1.1734, grad_fn=<NllLossBackward>)
# Error en la iteración: 617 tensor(1.1728, grad_fn=<NllLossBackward>)
# Error en la iteración: 618 tensor(1.1717, grad_fn=<NllLossBackward>)
# Error en la iteración: 619 tensor(1.1714, grad_fn=<NllLossBackward>)
# Error en la iteración: 620 tensor(1.1712, grad_fn=<NllLossBackward>)
# Error en la iteración: 621 tensor(1.1709, grad_fn=<NllLossBackward>)
# Error en la iteración: 622 tensor(1.1707, grad_fn=<NllLossBackward>)
# Error en la iteración: 623 tensor(1.1709, grad_fn=<NllLossBackward>)
# Error en la iteración: 624 tensor(1.1709, grad_fn=<NllLossBackward>)
# Error en la iteración: 625 tensor(1.1704, grad_fn=<NllLossBackward>)
# Error en la iteración: 626 tensor(1.1695, grad_fn=<NllLossBackward>)
# Error en la iteración: 627 tensor(1.1691, grad_fn=<NllLossBackward>)
# Error en la iteración: 628 tensor(1.1685, grad_fn=<NllLossBackward>)
# Error en la iteración: 629 tensor(1.1683, grad_fn=<NllLossBackward>)
# Error en la iteración: 630 tensor(1.1687, grad_fn=<NllLossBackward>)
# Error en la iteración: 631 tensor(1.1692, grad_fn=<NllLossBackward>)
# Error en la iteración: 632 tensor(1.1690, grad_fn=<NllLossBackward>)
# Error en la iteración: 633 tensor(1.1680, grad_fn=<NllLossBackward>)
# Error en la iteración: 634 tensor(1.1671, grad_fn=<NllLossBackward>)
# Error en la iteración: 635 tensor(1.1668, grad_fn=<NllLossBackward>)
# Error en la iteración: 636 tensor(1.1667, grad_fn=<NllLossBackward>)
# Error en la iteración: 637 tensor(1.1668, grad_fn=<NllLossBackward>)
# Error en la iteración: 638 tensor(1.1671, grad_fn=<NllLossBackward>)
# Error en la iteración: 639 tensor(1.1673, grad_fn=<NllLossBackward>)
# Error en la iteración: 640 tensor(1.1675, grad_fn=<NllLossBackward>)
# Error en la iteración: 641 tensor(1.1662, grad_fn=<NllLossBackward>)
# Error en la iteración: 642 tensor(1.1650, grad_fn=<NllLossBackward>)
# Error en la iteración: 643 tensor(1.1647, grad_fn=<NllLossBackward>)
# Error en la iteración: 644 tensor(1.1647, grad_fn=<NllLossBackward>)
# Error en la iteración: 645 tensor(1.1646, grad_fn=<NllLossBackward>)
# Error en la iteración: 646 tensor(1.1647, grad_fn=<NllLossBackward>)
# Error en la iteración: 647 tensor(1.1649, grad_fn=<NllLossBackward>)
# Error en la iteración: 648 tensor(1.1645, grad_fn=<NllLossBackward>)
# Error en la iteración: 649 tensor(1.1637, grad_fn=<NllLossBackward>)
# Error en la iteración: 650 tensor(1.1627, grad_fn=<NllLossBackward>)
# Error en la iteración: 651 tensor(1.1625, grad_fn=<NllLossBackward>)
# Error en la iteración: 652 tensor(1.1623, grad_fn=<NllLossBackward>)
# Error en la iteración: 653 tensor(1.1624, grad_fn=<NllLossBackward>)
# Error en la iteración: 654 tensor(1.1627, grad_fn=<NllLossBackward>)
# Error en la iteración: 655 tensor(1.1635, grad_fn=<NllLossBackward>)
# Error en la iteración: 656 tensor(1.1632, grad_fn=<NllLossBackward>)
# Error en la iteración: 657 tensor(1.1622, grad_fn=<NllLossBackward>)
# Error en la iteración: 658 tensor(1.1610, grad_fn=<NllLossBackward>)
# Error en la iteración: 659 tensor(1.1606, grad_fn=<NllLossBackward>)
# Error en la iteración: 660 tensor(1.1606, grad_fn=<NllLossBackward>)
# Error en la iteración: 661 tensor(1.1609, grad_fn=<NllLossBackward>)
# Error en la iteración: 662 tensor(1.1614, grad_fn=<NllLossBackward>)
# Error en la iteración: 663 tensor(1.1615, grad_fn=<NllLossBackward>)
# Error en la iteración: 664 tensor(1.1605, grad_fn=<NllLossBackward>)
# Error en la iteración: 665 tensor(1.1595, grad_fn=<NllLossBackward>)
# Error en la iteración: 666 tensor(1.1593, grad_fn=<NllLossBackward>)
# Error en la iteración: 667 tensor(1.1593, grad_fn=<NllLossBackward>)
# Error en la iteración: 668 tensor(1.1596, grad_fn=<NllLossBackward>)
# Error en la iteración: 669 tensor(1.1600, grad_fn=<NllLossBackward>)
# Error en la iteración: 670 tensor(1.1599, grad_fn=<NllLossBackward>)
# Error en la iteración: 671 tensor(1.1590, grad_fn=<NllLossBackward>)
# Error en la iteración: 672 tensor(1.1581, grad_fn=<NllLossBackward>)
# Error en la iteración: 673 tensor(1.1577, grad_fn=<NllLossBackward>)
# Error en la iteración: 674 tensor(1.1576, grad_fn=<NllLossBackward>)
# Error en la iteración: 675 tensor(1.1579, grad_fn=<NllLossBackward>)
# Error en la iteración: 676 tensor(1.1578, grad_fn=<NllLossBackward>)
# Error en la iteración: 677 tensor(1.1562, grad_fn=<NllLossBackward>)
# Error en la iteración: 678 tensor(1.1549, grad_fn=<NllLossBackward>)
# Error en la iteración: 679 tensor(1.1543, grad_fn=<NllLossBackward>)
# Error en la iteración: 680 tensor(1.1542, grad_fn=<NllLossBackward>)
# Error en la iteración: 681 tensor(1.1536, grad_fn=<NllLossBackward>)
# Error en la iteración: 682 tensor(1.1522, grad_fn=<NllLossBackward>)
# Error en la iteración: 683 tensor(1.1512, grad_fn=<NllLossBackward>)
# Error en la iteración: 684 tensor(1.1507, grad_fn=<NllLossBackward>)
# Error en la iteración: 685 tensor(1.1506, grad_fn=<NllLossBackward>)
# Error en la iteración: 686 tensor(1.1500, grad_fn=<NllLossBackward>)
# Error en la iteración: 687 tensor(1.1494, grad_fn=<NllLossBackward>)
# Error en la iteración: 688 tensor(1.1490, grad_fn=<NllLossBackward>)
# Error en la iteración: 689 tensor(1.1487, grad_fn=<NllLossBackward>)
# Error en la iteración: 690 tensor(1.1486, grad_fn=<NllLossBackward>)
# Error en la iteración: 691 tensor(1.1487, grad_fn=<NllLossBackward>)
# Error en la iteración: 692 tensor(1.1485, grad_fn=<NllLossBackward>)
# Error en la iteración: 693 tensor(1.1482, grad_fn=<NllLossBackward>)
# Error en la iteración: 694 tensor(1.1478, grad_fn=<NllLossBackward>)
# Error en la iteración: 695 tensor(1.1476, grad_fn=<NllLossBackward>)
# Error en la iteración: 696 tensor(1.1474, grad_fn=<NllLossBackward>)
# ...
# Error en la iteración: 769 tensor(1.1274, grad_fn=<NllLossBackward>)
# Error en la iteración: 770 tensor(1.1263, grad_fn=<NllLossBackward>)
# Error en la iteración: 771 tensor(1.1258, grad_fn=<NllLossBackward>)
# Error en la iteración: 772 tensor(1.1255, grad_fn=<NllLossBackward>)
# Error en la iteración: 773 tensor(1.1253, grad_fn=<NllLossBackward>)
# Error en la iteración: 774 tensor(1.1249, grad_fn=<NllLossBackward>)
# Error en la iteración: 775 tensor(1.1249, grad_fn=<NllLossBackward>)
# Error en la iteración: 776 tensor(1.1253, grad_fn=<NllLossBackward>)
# Error en la iteración: 777 tensor(1.1256, grad_fn=<NllLossBackward>)
# Error en la iteración: 778 tensor(1.1254, grad_fn=<NllLossBackward>)
# Error en la iteración: 779 tensor(1.1248, grad_fn=<NllLossBackward>)
# Error en la iteración: 780 tensor(1.1241, grad_fn=<NllLossBackward>)
# Error en la iteración: 781 tensor(1.1236, grad_fn=<NllLossBackward>)
# Error en la iteración: 782 tensor(1.1234, grad_fn=<NllLossBackward>)
# Error en la iteración: 783 tensor(1.1236, grad_fn=<NllLossBackward>)
# Error en la iteración: 784 tensor(1.1239, grad_fn=<NllLossBackward>)
# Error en la iteración: 785 tensor(1.1241, grad_fn=<NllLossBackward>)
# Error en la iteración: 786 tensor(1.1241, grad_fn=<NllLossBackward>)
# Error en la iteración: 787 tensor(1.1237, grad_fn=<NllLossBackward>)
# Error en la iteración: 788 tensor(1.1231, grad_fn=<NllLossBackward>)
# Error en la iteración: 789 tensor(1.1230, grad_fn=<NllLossBackward>)
# Error en la iteración: 790 tensor(1.1224, grad_fn=<NllLossBackward>)
# Error en la iteración: 791 tensor(1.1217, grad_fn=<NllLossBackward>)
# Error en la iteración: 792 tensor(1.1213, grad_fn=<NllLossBackward>)
# Error en la iteración: 793 tensor(1.1216, grad_fn=<NllLossBackward>)
# Error en la iteración: 794 tensor(1.1220, grad_fn=<NllLossBackward>)
# Error en la iteración: 795 tensor(1.1219, grad_fn=<NllLossBackward>)
# Error en la iteración: 796 tensor(1.1213, grad_fn=<NllLossBackward>)
# Error en la iteración: 797 tensor(1.1202, grad_fn=<NllLossBackward>)
# Error en la iteración: 798 tensor(1.1194, grad_fn=<NllLossBackward>)
# Error en la iteración: 799 tensor(1.1189, grad_fn=<NllLossBackward>)
# Error en la iteración: 800 tensor(1.1182, grad_fn=<NllLossBackward>)
# Error en la iteración: 801 tensor(1.1178, grad_fn=<NllLossBackward>)
# Error en la iteración: 802 tensor(1.1180, grad_fn=<NllLossBackward>)
# Error en la iteración: 803 tensor(1.1182, grad_fn=<NllLossBackward>)
# Error en la iteración: 804 tensor(1.1184, grad_fn=<NllLossBackward>)
# Error en la iteración: 805 tensor(1.1175, grad_fn=<NllLossBackward>)
# Error en la iteración: 806 tensor(1.1164, grad_fn=<NllLossBackward>)
# Error en la iteración: 807 tensor(1.1158, grad_fn=<NllLossBackward>)
# Error en la iteración: 808 tensor(1.1160, grad_fn=<NllLossBackward>)
# Error en la iteración: 809 tensor(1.1157, grad_fn=<NllLossBackward>)
# Error en la iteración: 810 tensor(1.1152, grad_fn=<NllLossBackward>)
# Error en la iteración: 811 tensor(1.1152, grad_fn=<NllLossBackward>)
# Error en la iteración: 812 tensor(1.1156, grad_fn=<NllLossBackward>)
# Error en la iteración: 813 tensor(1.1163, grad_fn=<NllLossBackward>)
# Error en la iteración: 814 tensor(1.1159, grad_fn=<NllLossBackward>)
# Error en la iteración: 815 tensor(1.1146, grad_fn=<NllLossBackward>)
# Error en la iteración: 816 tensor(1.1139, grad_fn=<NllLossBackward>)
# Error en la iteración: 817 tensor(1.1141, grad_fn=<NllLossBackward>)
# Error en la iteración: 818 tensor(1.1140, grad_fn=<NllLossBackward>)
# Error en la iteración: 819 tensor(1.1140, grad_fn=<NllLossBackward>)
# Error en la iteración: 820 tensor(1.1141, grad_fn=<NllLossBackward>)
# Error en la iteración: 821 tensor(1.1144, grad_fn=<NllLossBackward>)
# Error en la iteración: 822 tensor(1.1141, grad_fn=<NllLossBackward>)
# Error en la iteración: 823 tensor(1.1138, grad_fn=<NllLossBackward>)
# Error en la iteración: 824 tensor(1.1134, grad_fn=<NllLossBackward>)
# Error en la iteración: 825 tensor(1.1129, grad_fn=<NllLossBackward>)
# Error en la iteración: 826 tensor(1.1122, grad_fn=<NllLossBackward>)
# Error en la iteración: 827 tensor(1.1120, grad_fn=<NllLossBackward>)
# Error en la iteración: 828 tensor(1.1118, grad_fn=<NllLossBackward>)
# Error en la iteración: 829 tensor(1.1123, grad_fn=<NllLossBackward>)
# Error en la iteración: 830 tensor(1.1127, grad_fn=<NllLossBackward>)
# Error en la iteración: 831 tensor(1.1122, grad_fn=<NllLossBackward>)
# Error en la iteración: 832 tensor(1.1113, grad_fn=<NllLossBackward>)
# Error en la iteración: 833 tensor(1.1101, grad_fn=<NllLossBackward>)
# Error en la iteración: 834 tensor(1.1097, grad_fn=<NllLossBackward>)
# Error en la iteración: 835 tensor(1.1094, grad_fn=<NllLossBackward>)
# Error en la iteración: 836 tensor(1.1090, grad_fn=<NllLossBackward>)
# Error en la iteración: 837 tensor(1.1086, grad_fn=<NllLossBackward>)
# Error en la iteración: 838 tensor(1.1087, grad_fn=<NllLossBackward>)
# Error en la iteración: 839 tensor(1.1089, grad_fn=<NllLossBackward>)
# Error en la iteración: 840 tensor(1.1089, grad_fn=<NllLossBackward>)
# Error en la iteración: 841 tensor(1.1080, grad_fn=<NllLossBackward>)
# Error en la iteración: 842 tensor(1.1069, grad_fn=<NllLossBackward>)
# Error en la iteración: 843 tensor(1.1065, grad_fn=<NllLossBackward>)
# Error en la iteración: 844 tensor(1.1066, grad_fn=<NllLossBackward>)
# Error en la iteración: 845 tensor(1.1064, grad_fn=<NllLossBackward>)
# Error en la iteración: 846 tensor(1.1066, grad_fn=<NllLossBackward>)
# Error en la iteración: 847 tensor(1.1067, grad_fn=<NllLossBackward>)
# Error en la iteración: 848 tensor(1.1067, grad_fn=<NllLossBackward>)
# Error en la iteración: 849 tensor(1.1065, grad_fn=<NllLossBackward>)
# Error en la iteración: 850 tensor(1.1058, grad_fn=<NllLossBackward>)
# Error en la iteración: 851 tensor(1.1053, grad_fn=<NllLossBackward>)
# Error en la iteración: 852 tensor(1.1051, grad_fn=<NllLossBackward>)
# Error en la iteración: 853 tensor(1.1049, grad_fn=<NllLossBackward>)
# Error en la iteración: 854 tensor(1.1046, grad_fn=<NllLossBackward>)
# Error en la iteración: 855 tensor(1.1045, grad_fn=<NllLossBackward>)
# Error en la iteración: 856 tensor(1.1049, grad_fn=<NllLossBackward>)
# Error en la iteración: 857 tensor(1.1056, grad_fn=<NllLossBackward>)
# Error en la iteración: 858 tensor(1.1059, grad_fn=<NllLossBackward>)
# Error en la iteración: 859 tensor(1.1052, grad_fn=<NllLossBackward>)
# Error en la iteración: 860 tensor(1.1042, grad_fn=<NllLossBackward>)
# Error en la iteración: 861 tensor(1.1037, grad_fn=<NllLossBackward>)
# Error en la iteración: 862 tensor(1.1040, grad_fn=<NllLossBackward>)
# Error en la iteración: 863 tensor(1.1037, grad_fn=<NllLossBackward>)
# Error en la iteración: 864 tensor(1.1031, grad_fn=<NllLossBackward>)
# Error en la iteración: 865 tensor(1.1030, grad_fn=<NllLossBackward>)
# Error en la iteración: 866 tensor(1.1033, grad_fn=<NllLossBackward>)
# Error en la iteración: 867 tensor(1.1033, grad_fn=<NllLossBackward>)
# Error en la iteración: 868 tensor(1.1026, grad_fn=<NllLossBackward>)
# Error en la iteración: 869 tensor(1.1012, grad_fn=<NllLossBackward>)
# Error en la iteración: 870 tensor(1.1006, grad_fn=<NllLossBackward>)
# Error en la iteración: 871 tensor(1.1001, grad_fn=<NllLossBackward>)
# Error en la iteración: 872 tensor(1.1000, grad_fn=<NllLossBackward>)
# Error en la iteración: 873 tensor(1.1002, grad_fn=<NllLossBackward>)
# Error en la iteración: 874 tensor(1.1005, grad_fn=<NllLossBackward>)
# Error en la iteración: 875 tensor(1.1002, grad_fn=<NllLossBackward>)
# Error en la iteración: 876 tensor(1.0991, grad_fn=<NllLossBackward>)
# Error en la iteración: 877 tensor(1.0984, grad_fn=<NllLossBackward>)
# Error en la iteración: 878 tensor(1.0984, grad_fn=<NllLossBackward>)
# Error en la iteración: 879 tensor(1.0983, grad_fn=<NllLossBackward>)
# Error en la iteración: 880 tensor(1.0981, grad_fn=<NllLossBackward>)
# Error en la iteración: 881 tensor(1.0980, grad_fn=<NllLossBackward>)
# Error en la iteración: 882 tensor(1.0982, grad_fn=<NllLossBackward>)
# Error en la iteración: 883 tensor(1.0985, grad_fn=<NllLossBackward>)
# Error en la iteración: 884 tensor(1.0981, grad_fn=<NllLossBackward>)
# Error en la iteración: 885 tensor(1.0976, grad_fn=<NllLossBackward>)
# Error en la iteración: 886 tensor(1.0974, grad_fn=<NllLossBackward>)
# Error en la iteración: 887 tensor(1.0972, grad_fn=<NllLossBackward>)
# Error en la iteración: 888 tensor(1.0969, grad_fn=<NllLossBackward>)
# Error en la iteración: 889 tensor(1.0973, grad_fn=<NllLossBackward>)
# Error en la iteración: 890 tensor(1.0980, grad_fn=<NllLossBackward>)
# Error en la iteración: 891 tensor(1.0979, grad_fn=<NllLossBackward>)
# Error en la iteración: 892 tensor(1.0971, grad_fn=<NllLossBackward>)
# Error en la iteración: 893 tensor(1.0967, grad_fn=<NllLossBackward>)
# Error en la iteración: 894 tensor(1.0965, grad_fn=<NllLossBackward>)
# Error en la iteración: 895 tensor(1.0963, grad_fn=<NllLossBackward>)
# Error en la iteración: 896 tensor(1.0959, grad_fn=<NllLossBackward>)
# Error en la iteración: 897 tensor(1.0956, grad_fn=<NllLossBackward>)
# Error en la iteración: 898 tensor(1.0958, grad_fn=<NllLossBackward>)
# Error en la iteración: 899 tensor(1.0964, grad_fn=<NllLossBackward>)
# Error en la iteración: 900 tensor(1.0961, grad_fn=<NllLossBackward>)
# Error en la iteración: 901 tensor(1.0949, grad_fn=<NllLossBackward>)
# Error en la iteración: 902 tensor(1.0945, grad_fn=<NllLossBackward>)
# Error en la iteración: 903 tensor(1.0944, grad_fn=<NllLossBackward>)
# Error en la iteración: 904 tensor(1.0941, grad_fn=<NllLossBackward>)
# Error en la iteración: 905 tensor(1.0938, grad_fn=<NllLossBackward>)
# Error en la iteración: 906 tensor(1.0936, grad_fn=<NllLossBackward>)
# Error en la iteración: 907 tensor(1.0928, grad_fn=<NllLossBackward>)
# Error en la iteración: 908 tensor(1.0919, grad_fn=<NllLossBackward>)
# Error en la iteración: 909 tensor(1.0913, grad_fn=<NllLossBackward>)
# Error en la iteración: 910 tensor(1.0912, grad_fn=<NllLossBackward>)
# Error en la iteración: 911 tensor(1.0915, grad_fn=<NllLossBackward>)
# Error en la iteración: 912 tensor(1.0915, grad_fn=<NllLossBackward>)
# Error en la iteración: 913 tensor(1.0908, grad_fn=<NllLossBackward>)
# Error en la iteración: 914 tensor(1.0904, grad_fn=<NllLossBackward>)
# Error en la iteración: 915 tensor(1.0903, grad_fn=<NllLossBackward>)
# Error en la iteración: 916 tensor(1.0903, grad_fn=<NllLossBackward>)
# Error en la iteración: 917 tensor(1.0900, grad_fn=<NllLossBackward>)
# Error en la iteración: 918 tensor(1.0897, grad_fn=<NllLossBackward>)
# Error en la iteración: 919 tensor(1.0898, grad_fn=<NllLossBackward>)
# Error en la iteración: 920 tensor(1.0902, grad_fn=<NllLossBackward>)
# Error en la iteración: 921 tensor(1.0900, grad_fn=<NllLossBackward>)
# Error en la iteración: 922 tensor(1.0891, grad_fn=<NllLossBackward>)
# Error en la iteración: 923 tensor(1.0882, grad_fn=<NllLossBackward>)
# Error en la iteración: 924 tensor(1.0878, grad_fn=<NllLossBackward>)
# Error en la iteración: 925 tensor(1.0879, grad_fn=<NllLossBackward>)
# Error en la iteración: 926 tensor(1.0880, grad_fn=<NllLossBackward>)
# Error en la iteración: 927 tensor(1.0875, grad_fn=<NllLossBackward>)
# Error en la iteración: 928 tensor(1.0873, grad_fn=<NllLossBackward>)
# Error en la iteración: 929 tensor(1.0878, grad_fn=<NllLossBackward>)
# Error en la iteración: 930 tensor(1.0884, grad_fn=<NllLossBackward>)
# Error en la iteración: 931 tensor(1.0881, grad_fn=<NllLossBackward>)
# Error en la iteración: 932 tensor(1.0866, grad_fn=<NllLossBackward>)
# Error en la iteración: 933 tensor(1.0858, grad_fn=<NllLossBackward>)
# Error en la iteración: 934 tensor(1.0858, grad_fn=<NllLossBackward>)
# Error en la iteración: 935 tensor(1.0860, grad_fn=<NllLossBackward>)
# Error en la iteración: 936 tensor(1.0857, grad_fn=<NllLossBackward>)
# Error en la iteración: 937 tensor(1.0851, grad_fn=<NllLossBackward>)
# Error en la iteración: 938 tensor(1.0851, grad_fn=<NllLossBackward>)
# Error en la iteración: 939 tensor(1.0858, grad_fn=<NllLossBackward>)
# Error en la iteración: 940 tensor(1.0860, grad_fn=<NllLossBackward>)
# Error en la iteración: 941 tensor(1.0854, grad_fn=<NllLossBackward>)
# Error en la iteración: 942 tensor(1.0843, grad_fn=<NllLossBackward>)
# Error en la iteración: 943 tensor(1.0837, grad_fn=<NllLossBackward>)
# Error en la iteración: 944 tensor(1.0837, grad_fn=<NllLossBackward>)
# Error en la iteración: 945 tensor(1.0840, grad_fn=<NllLossBackward>)
# Error en la iteración: 946 tensor(1.0836, grad_fn=<NllLossBackward>)
# Error en la iteración: 947 tensor(1.0829, grad_fn=<NllLossBackward>)
# Error en la iteración: 948 tensor(1.0827, grad_fn=<NllLossBackward>)
# Error en la iteración: 949 tensor(1.0831, grad_fn=<NllLossBackward>)
# Error en la iteración: 950 tensor(1.0839, grad_fn=<NllLossBackward>)
# Error en la iteración: 951 tensor(1.0843, grad_fn=<NllLossBackward>)
# Error en la iteración: 952 tensor(1.0834, grad_fn=<NllLossBackward>)
# Error en la iteración: 953 tensor(1.0820, grad_fn=<NllLossBackward>)
# Error en la iteración: 954 tensor(1.0816, grad_fn=<NllLossBackward>)
# Error en la iteración: 955 tensor(1.0820, grad_fn=<NllLossBackward>)
# Error en la iteración: 956 tensor(1.0816, grad_fn=<NllLossBackward>)
# Error en la iteración: 957 tensor(1.0809, grad_fn=<NllLossBackward>)
# Error en la iteración: 958 tensor(1.0806, grad_fn=<NllLossBackward>)
# Error en la iteración: 959 tensor(1.0812, grad_fn=<NllLossBackward>)
# Error en la iteración: 960 tensor(1.0821, grad_fn=<NllLossBackward>)
# Error en la iteración: 961 tensor(1.0817, grad_fn=<NllLossBackward>)
# Error en la iteración: 962 tensor(1.0800, grad_fn=<NllLossBackward>)
# Error en la iteración: 963 tensor(1.0794, grad_fn=<NllLossBackward>)
# Error en la iteración: 964 tensor(1.0795, grad_fn=<NllLossBackward>)
# Error en la iteración: 965 tensor(1.0794, grad_fn=<NllLossBackward>)
# Error en la iteración: 966 tensor(1.0788, grad_fn=<NllLossBackward>)
# Error en la iteración: 967 tensor(1.0787, grad_fn=<NllLossBackward>)
# Error en la iteración: 968 tensor(1.0787, grad_fn=<NllLossBackward>)
# Error en la iteración: 969 tensor(1.0792, grad_fn=<NllLossBackward>)
# Error en la iteración: 970 tensor(1.0791, grad_fn=<NllLossBackward>)
# Error en la iteración: 971 tensor(1.0782, grad_fn=<NllLossBackward>)
# Error en la iteración: 972 tensor(1.0774, grad_fn=<NllLossBackward>)
# Error en la iteración: 973 tensor(1.0771, grad_fn=<NllLossBackward>)
# Error en la iteración: 974 tensor(1.0768, grad_fn=<NllLossBackward>)
# Error en la iteración: 975 tensor(1.0767, grad_fn=<NllLossBackward>)
# Error en la iteración: 976 tensor(1.0766, grad_fn=<NllLossBackward>)
# Error en la iteración: 977 tensor(1.0769, grad_fn=<NllLossBackward>)
# Error en la iteración: 978 tensor(1.0772, grad_fn=<NllLossBackward>)
# Error en la iteración: 979 tensor(1.0774, grad_fn=<NllLossBackward>)
# Error en la iteración: 980 tensor(1.0765, grad_fn=<NllLossBackward>)
# Error en la iteración: 981 tensor(1.0754, grad_fn=<NllLossBackward>)
# Error en la iteración: 982 tensor(1.0754, grad_fn=<NllLossBackward>)
# Error en la iteración: 983 tensor(1.0756, grad_fn=<NllLossBackward>)
# Error en la iteración: 984 tensor(1.0750, grad_fn=<NllLossBackward>)
# Error en la iteración: 985 tensor(1.0745, grad_fn=<NllLossBackward>)
# Error en la iteración: 986 tensor(1.0746, grad_fn=<NllLossBackward>)
# Error en la iteración: 987 tensor(1.0750, grad_fn=<NllLossBackward>)
# Error en la iteración: 988 tensor(1.0756, grad_fn=<NllLossBackward>)
# Error en la iteración: 989 tensor(1.0751, grad_fn=<NllLossBackward>)
# Error en la iteración: 990 tensor(1.0739, grad_fn=<NllLossBackward>)
# Error en la iteración: 991 tensor(1.0735, grad_fn=<NllLossBackward>)
# Error en la iteración: 992 tensor(1.0737, grad_fn=<NllLossBackward>)
# Error en la iteración: 993 tensor(1.0735, grad_fn=<NllLossBackward>)
# Error en la iteración: 994 tensor(1.0733, grad_fn=<NllLossBackward>)
# Error en la iteración: 995 tensor(1.0731, grad_fn=<NllLossBackward>)
# Error en la iteración: 996 tensor(1.0733, grad_fn=<NllLossBackward>)
# Error en la iteración: 997 tensor(1.0734, grad_fn=<NllLossBackward>)
# Error en la iteración: 998 tensor(1.0734, grad_fn=<NllLossBackward>)
# Error en la iteración: 999 tensor(1.0728, grad_fn=<NllLossBackward>)

# %% [markdown]
# # Precisión

# %% [markdown]
# ## Precisión en el conjunto de entrenamiento.

# %%
nn_Musica.accurNet(trainset)
# Out:
# 59.46826215247644

# %% [markdown]
# ## Matriz de confusión para el conjunto de entrenamiento.

# %%
nn_Musica.confusion(trainset, 22)

# %% [markdown]
# ## Precisión en el conjunto de prueba.

# %%
nn_Musica.accurNet(testset)
# Out:
# 53.46388412426148

# %% [markdown]
# ## Matriz de confusión para el conjunto de prueba.

# %%
nn_Musica.confusion(testset, 22)

# %% [markdown]
# # Guardado del modelo.
# Finalmente guardamos el modelo si se desean hacer pruebas posteriores y evitar el entrenamiento otra vez.

# %%
torch.save(nn_Musica.state_dict(), 'model/model1000')

# %% [markdown]
# # Cargar el modelo
# Si se desea cargar el modelo basta con ejecutar las siguientes instrucciones.

# %%
nn_Musica_2 = Musica(29, 350, 22)
nn_Musica_2.load_state_dict(torch.load('model/model1000'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Conclusiones sobre el proyecto
#
# Hicimos varias pruebas para este proyecto y terminamos encontrando que el mejor modelo es el presentado en este notebook.
#
# Nuestros porcentajes de exactitud son de más del 50 por ciento tanto en el conjuntos de prueba como en el de entrenamiento. Se esperaría un porcentaje más elevado pero haciendo un análisis más exahaustivo de los resultados dados podemos ver que tenemos un clasificador bastante bueno. Si observamos las matrices de confusión podemos encontrar que muchas canciones no son clasificadas en su género asignado pero si se asignan a un género musical muy parecido, por ejemplo podemos observar que canciones de reggae son clasificadas como de reggaeton y viceversa, esto es correcto, ya que las canciones comparten mucho parecido en sus características. Si hacemos una análisis independiente de todas las clasificaciones no correspondientes podemos encontrar que los géneros a las que fueron clasificadas tienen sentido.
#
# De ahí que creemos hemos cumplido nuestro objetivo.
