# %% [markdown]
# # Facultad de Ciencias, UNAM.
# # Proyecto Redes Neuronales:
#
# ## Clasificador de géneros musicales
#
# ### Integrantes:
# - Jorge Francisco Cortés López - 314330981
# - Sandra del Mar Soto Corderi - 3157070267

# %% [markdown]
# ## Introducción y motivación.
# Uno de los retos más interesantes para la inteligencia artificial es el de intentar que clasifiquemos o generemos arte usando diferentes herramientas como las redes neuronales, ya que hasta la fecha no existe un algoritmo o clasificador en el que pasemos una canción o ciertos atributos de una canción y nos diga a qué género pertenece.
#
# Para éste proyecto intentamos ver hasta donde podemos llegar a clasificar el conjunto de canciones que obtuvimos con ciertas características musicales como: tono, tiempo, tempo, popularidad, entre otros.
#
# Se utilizó una red multicapa, ya que queríamos ver hasta donde podíamos explotar sus capacidades, existen otras arquitecturas más modernas como las redes convolucionales, sin embargo era mucho más complejo y difícil obtener los datos, por lo que decidimos optar por una arquitectura más sencilla y ver hasta donde nos podía llevar.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# Si se tiene GPU Nvidia se puede descomentar.
#device = "cuda"
device = "cpu"

# %% [markdown]
# # Procesamiento de datos
# Lo primero que hacemos es cargar los datos con ayuda de la biblioteca pandas, que es de mucha utilidad para cargar y manipular datos en python. Mostramos un sample de los datos.

# %%
music_data = 'data/musicdata.csv'
music_data = pd.read_csv(music_data)
music_data.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %% [markdown]
# ## Limpieza de datos
# Vemos si existen canciones duplicadas en diferentes géneros, en éste caso hay canciones que están en varios géneros, por lo que lo mejor será quitarlas.
#
# Además de ésto, quitamos algunos géneros que no cuentan con muchas canciones o que consideramos que pudieran afectar al desempeño de la red ya que por ejemplo Children's Music no lo consideramos un género como tal.

# %%
# Duplicados
music_data = music_data.drop_duplicates(subset=['track_name'], keep='first', ignore_index=True)

# Géneros que consideramos para quitar 
# (Muchas canciones de Hip Hop se pueden categorizar como Rap)
music_data.drop(music_data[music_data.genre == 'Rap'].index, inplace=True)
music_data.drop(music_data[music_data.genre == 'Children\'s Music'].index, inplace=True)
music_data.drop(music_data[music_data.genre == 'Children’s Music'].index, inplace=True)
music_data.drop(music_data[music_data.genre == 'A Capella'].index, inplace=True)
music_data.drop(music_data[music_data.genre == 'Indie'].index, inplace=True)

# %% [markdown]
# Quitamos también las características que no nos interesan, en éste caso:
#
# * artist_name
# * track_name
# * track_id
# * duration_ms
#
# no nos interesan, ya que ésto en un principio no tendría porqué influenciar el género de una canción.

# %%
unused_col = ['artist_name', 'track_name', 'track_id', 'duration_ms']
music_data = music_data.drop(columns=unused_col)

# %% [markdown]
# Finalmente, vemos si hay ejemplares que tengan algún dato faltante.

# %%
music_data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Codificación y normalización
# Una vez que nuestros datos están limpios podemos hacer la codificación para nuestra red neuronal, vamos que hay algunos que necesitan ser normalizados como popularity, loudness y tempo. Sin embargo también vemos que key, mode y time signature necesitan ser codificados.

# %%
# Normalizamos las columnas correspondientes.
mms = MinMaxScaler()
music_data[['popularity','loudness','tempo']] = \
            mms.fit_transform(music_data[['popularity','loudness','tempo']])

# %%
# Codificamos a One hot encoding las columnas necesarias.
music_data = \
    pd.get_dummies(data=music_data, columns=['key', 'mode', 'time_signature'], dtype=float)

# %% [markdown]
# Luego de codificar y normalizar los ejemplares, aplicamos codificamos igualmente las clases con ayuda de la clase LabelEncoder.

# %%
le = LabelEncoder()
music_data['genre'] = le.fit_transform(music_data.genre.values).astype(float)

# %% [markdown]
# Finalmente vemos cómo quedaron las columnas de los datos ya procesados y limpios para proseguir con los demás pasos

# %%
music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139919 entries, 0 to 148614
# Data columns (total 30 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   genre               139919 non-null  float64
#  1   popularity          139919 non-null  float64
#  2   acousticness        139919 non-null  float64
#  3   danceability        139919 non-null  float64
#  4   energy              139919 non-null  float64
#  5   instrumentalness    139919 non-null  float64
#  6   liveness            139919 non-null  float64
#  7   loudness            139919 non-null  float64
#  8   speechiness         139919 non-null  float64
#  9   tempo               139919 non-null  float64
#  10  valence             139919 non-null  float64
#  11  key_A               139919 non-null  float64
#  12  key_A#              139919 non-null  float64
#  13  key_B               139919 non-null  float64
#  14  key_C               139919 non-null  float64
#  15  key_C#              139919 non-null  float64
#  16  key_D               139919 non-null  float64
#  17  key_D#              139919 non-null  float64
#  18  key_E               139919 non-null  float64
#  19  key_F               139919 non-null  float64
#  20  key_F#              139919 non-null  float64
#  21  key_G               139919 non-null  float64
#  22  key_G#              139919 non-null  float64
#  23  mode_Major          139919 non-null  float64
#  24  mode_Minor          139919 non-null  float64
#  25  time_signature_0/4  139919 non-null  float64
#  26  time_signature_1/4  139919 non-null  float64
#  27  time_signature_3/4  139919 non-null  float64
#  28  time_signature_4/4  139919 non-null  float64
#  29  time_signature_5/4  139919 non-null  float64
# dtypes: float64(30)
# memory usage: 33.1 MB

# %% [markdown]
# ## División del conjunto de datos
# Una vez que hemos limpiado el conjunto de datos proseguimos a hacer la división en los conjuntos de entrenamiento y prueba.

# %%
Y = music_data.pop('genre')
X = music_data

# %%
# Hacemos la división con una proporción de 70% - 30%.
X_train, X_test, y_train, y_test = \
    train_test_split(X, Y, test_size=0.3,random_state=7, stratify=Y)

# %% [markdown]
# # Clase de dataset para Pytorch
# Una vez que ya tenemos los datos separados, creamos la clase que hereda de Dataset en pytorch para facilitar el flujo entre la red neuronal y poder hacer el entrenamiento en lotes (batches).

# %%
class MusicDataset(Dataset):
    """Dataset de música de spotify"""
    
    def __init__(self, X, Y):
        """
        Args:
            X (pandas DataFrame): Datos.
            Y (pandas DataFrame): Labels.
        """
        self.X = X
        self.Y = Y
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        features = np.asarray(self.X.iloc[idx])
        label = np.asarray(self.Y.iloc[idx])
        return features, label

# %% [markdown]
# ## Instancias de objetos de datos para pytorch
# Una vez creada la clase para los datos de música, los instanciamos con el conjunto de entrenamiento y de prueba para pytorch como DataLoader.

# %%
# Entrenamiento:
trainset = MusicDataset(X = X_train, Y = y_train)
trainset = DataLoader(trainset, batch_size=15000) # Podemos cambiar el número de lotes.

# Prueba:
testset = MusicDataset(X = X_test, Y = y_test)
testset = DataLoader(testset, batch_size=5000)

# %% [markdown]
# # Modelo
# Ya teniendo los datos como DataLoader ahora nos enfocamos en el modelo.
#
# En éste proyecto decidimos utilizar la arquitectura de perceptrón multicapa, a continuación definimos el modelo y posteriormente haremos el entrenamiento de la red.
# Tenemos: 29 características de entrada y 22 de salida (22 géneros en total).
# Cada capa oculta cuenta con 350 neuronas. A continuación definimos y mostramos el modelo.

# %% [markdown]
# <img src="images/nn.svg">

# %%
class Musica(nn.Module):
    def __init__(self,input_size,hidden,output_size):
        '''
        Define las caracteristicas de una red completamente conectada 
        de tres capas, recibe la cantidad de elementos de entrada, el 
        número de capas ocultas y el número de elementos de salida. 
        Entre cada capa agrega una función de activación relu.
        '''
        super(Musica,self).__init__()
        #Declaramos las tres capas 
        self.fc1 = nn.Linear(input_size, hidden)
        self.fc2 = nn.Linear(hidden, hidden)
        self.fc3 = nn.Linear(hidden, hidden)
        self.fc4 = nn.Linear(hidden, output_size) 
        # Función de error.
        self.loss_fn = nn.CrossEntropyLoss()
        # Algoritmo de optimización.
        self.optimizer = optim.Adam(self.parameters(), lr=0.006)
        # Error actual de la red.
        self.loss = 0.0
        
    def forward(self,X):
        '''
        Define una función que de como resultado realizar la propagación
        hacia adelante de los elementos de X en la red definida.
        '''
        #Se activa la capa de entrada
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = F.relu(self.fc3(X))
        X = self.fc4(X)
        
        return F.log_softmax(X, dim=1)
        
    def back_propagate(self,X,Y):
        '''
        Define una función que realice la propagación hacia atras usando 
        la función de error de entropia cruzada.
        '''
        # Calculamos el error.
        self.loss = self.loss_fn(X,Y.long())
        
        #Vaciamos los gradientes, hacemos una propagación hacia atrás
        # y actualizamos pesos.
        self.optimizer.zero_grad()
        self.loss.backward()
        self.optimizer.step()
        
    def train(self,train_X,ciclos=100):
        '''
        Define una función de entrenamiento para la red, la cual utilice
        al conjunto de entrenamiento y el algoritmo de optimización que se 
        obtenga como parametro. Al finalizar los ciclos muestra la gráfica 
        del error.
        '''
        data_error = np.zeros(ciclos)
        
        for t in range(ciclos):
            # Para cada uno de los lotes.
            for data in train_X:
                X, Y = data
                X, Y = X.to(device), Y.to(device)
                
                # Feed forward.
                y_pred = self(X.float())
                
                # Back propagate.
                self.back_propagate(y_pred, Y)
                
                # Anexamos el error actual.
                data_error[t] = self.loss
            print("Error en la iteración: " + str(t) + " " + str(self.loss))
        
        # Graficamos el error.
        if ciclos > 1:
            plt.plot(np.arange(ciclos), data_error)
            plt.xlabel('Iteraciones')
            plt.ylabel('Error')
                
    def confusion(self,dataset,numClases):
        '''
        Muestra la matriz de confusión que presenta los valores actuales de
        la red, respecto al conjunto de datos que se decida usar.
        '''
        # Matriz de confusión inicial con dimensión correspondiente al número de clases.
        cmatrix = np.zeros([numClases,numClases], dtype=int)
        for data in dataset:
            X,Y = data
            X, Y = X.to(device), Y.to(device)
            #Se obtienen las predicciones de la data
            y_pred = self.forward(X.float())
            _, predicted = torch.max(y_pred.data, 1)
            # Se juntan los datos para obtener predicciones de las clases.
            stacked = torch.stack((predicted ,Y),dim=1)
            # Iteramos sobre las predicciones y las clases.
            for p in stacked:
                tl, pl = p.tolist()
                cmatrix[int(tl), int(pl)] = cmatrix[int(tl), int(pl)] + 1
        # Una vez calculada la matriz se grafica
        music_labels = le.classes_
        df_cm = pd.DataFrame(cmatrix, index = music_labels, columns = music_labels)
        plt.figure(figsize = (20,15))
        sns.set_theme(style="whitegrid")
        #Por cuestiones de estética y facilidad se usa heatmap
        sns.heatmap(df_cm, annot=True, robust=True, fmt="d", cmap="YlGnBu")
        plt.title("Matriz de confusión sin normalizar")
        plt.ylabel('Predicción')
        plt.xlabel('Actual')
        plt.show()
        
    # Accuracy de un conjunto de datos dentro de la RN.
    def accurNet(self, dataTest):
        correct = 0
        total = 0
        with torch.no_grad():
            for data in dataTest:
                X, Y = data
                X, Y = X.to(device), Y.to(device)

                y_pred = self.forward(X.float())

                _, predicted = torch.max(y_pred.data, 1)
                predicted = predicted.float()
                total += Y.size(0)
                correct += (predicted == Y).sum().item()
        return 100 * correct / total

# %% [markdown]
# # Entrenamiento
# A continuación creamos una instancia de la red neuronal y hacemos el entrenamiento.

# %%
# Instanciamos la red.
nn_Musica = Musica(29, 350, 22)
#nn_Musica.cuda() # Para cuda.

# %%
nn_Musica.train(trainset, ciclos=200)
# Out:
# Error en la iteración: 0 tensor(2.5548, grad_fn=<NllLossBackward>)
# Error en la iteración: 1 tensor(2.2365, grad_fn=<NllLossBackward>)
# Error en la iteración: 2 tensor(2.0112, grad_fn=<NllLossBackward>)
# Error en la iteración: 3 tensor(1.8841, grad_fn=<NllLossBackward>)
# Error en la iteración: 4 tensor(1.7593, grad_fn=<NllLossBackward>)
# Error en la iteración: 5 tensor(1.7013, grad_fn=<NllLossBackward>)
# Error en la iteración: 6 tensor(1.6548, grad_fn=<NllLossBackward>)
# Error en la iteración: 7 tensor(1.6268, grad_fn=<NllLossBackward>)
# Error en la iteración: 8 tensor(1.5953, grad_fn=<NllLossBackward>)
# Error en la iteración: 9 tensor(1.5830, grad_fn=<NllLossBackward>)
# Error en la iteración: 10 tensor(1.5670, grad_fn=<NllLossBackward>)
# Error en la iteración: 11 tensor(1.5533, grad_fn=<NllLossBackward>)
# Error en la iteración: 12 tensor(1.5325, grad_fn=<NllLossBackward>)
# Error en la iteración: 13 tensor(1.5044, grad_fn=<NllLossBackward>)
# Error en la iteración: 14 tensor(1.5138, grad_fn=<NllLossBackward>)
# Error en la iteración: 15 tensor(1.4996, grad_fn=<NllLossBackward>)
# Error en la iteración: 16 tensor(1.4993, grad_fn=<NllLossBackward>)
# Error en la iteración: 17 tensor(1.4694, grad_fn=<NllLossBackward>)
# Error en la iteración: 18 tensor(1.4596, grad_fn=<NllLossBackward>)
# Error en la iteración: 19 tensor(1.4607, grad_fn=<NllLossBackward>)
# Error en la iteración: 20 tensor(1.4390, grad_fn=<NllLossBackward>)
# Error en la iteración: 21 tensor(1.4397, grad_fn=<NllLossBackward>)
# Error en la iteración: 22 tensor(1.4211, grad_fn=<NllLossBackward>)
# Error en la iteración: 23 tensor(1.4189, grad_fn=<NllLossBackward>)
# Error en la iteración: 24 tensor(1.4206, grad_fn=<NllLossBackward>)
# Error en la iteración: 25 tensor(1.4021, grad_fn=<NllLossBackward>)
# Error en la iteración: 26 tensor(1.4041, grad_fn=<NllLossBackward>)
# Error en la iteración: 27 tensor(1.3912, grad_fn=<NllLossBackward>)
# Error en la iteración: 28 tensor(1.3908, grad_fn=<NllLossBackward>)
# Error en la iteración: 29 tensor(1.3927, grad_fn=<NllLossBackward>)
# Error en la iteración: 30 tensor(1.3983, grad_fn=<NllLossBackward>)
# Error en la iteración: 31 tensor(1.3942, grad_fn=<NllLossBackward>)
# Error en la iteración: 32 tensor(1.3941, grad_fn=<NllLossBackward>)
# Error en la iteración: 33 tensor(1.3600, grad_fn=<NllLossBackward>)
# Error en la iteración: 34 tensor(1.3722, grad_fn=<NllLossBackward>)
# Error en la iteración: 35 tensor(1.3601, grad_fn=<NllLossBackward>)
# Error en la iteración: 36 tensor(1.3631, grad_fn=<NllLossBackward>)
# Error en la iteración: 37 tensor(1.3556, grad_fn=<NllLossBackward>)
# Error en la iteración: 38 tensor(1.3484, grad_fn=<NllLossBackward>)
# Error en la iteración: 39 tensor(1.3514, grad_fn=<NllLossBackward>)
# Error en la iteración: 40 tensor(1.3402, grad_fn=<NllLossBackward>)
# Error en la iteración: 41 tensor(1.3367, grad_fn=<NllLossBackward>)
# Error en la iteración: 42 tensor(1.3449, grad_fn=<NllLossBackward>)
# Error en la iteración: 43 tensor(1.3473, grad_fn=<NllLossBackward>)
# Error en la iteración: 44 tensor(1.3346, grad_fn=<NllLossBackward>)
# Error en la iteración: 45 tensor(1.3290, grad_fn=<NllLossBackward>)
# Error en la iteración: 46 tensor(1.3139, grad_fn=<NllLossBackward>)
# Error en la iteración: 47 tensor(1.3043, grad_fn=<NllLossBackward>)
# Error en la iteración: 48 tensor(1.3200, grad_fn=<NllLossBackward>)
# Error en la iteración: 49 tensor(1.3055, grad_fn=<NllLossBackward>)
# Error en la iteración: 50 tensor(1.3043, grad_fn=<NllLossBackward>)
# Error en la iteración: 51 tensor(1.3025, grad_fn=<NllLossBackward>)
# Error en la iteración: 52 tensor(1.3064, grad_fn=<NllLossBackward>)
# Error en la iteración: 53 tensor(1.2925, grad_fn=<NllLossBackward>)
# Error en la iteración: 54 tensor(1.2973, grad_fn=<NllLossBackward>)
# Error en la iteración: 55 tensor(1.2918, grad_fn=<NllLossBackward>)
# Error en la iteración: 56 tensor(1.2794, grad_fn=<NllLossBackward>)
# Error en la iteración: 57 tensor(1.2747, grad_fn=<NllLossBackward>)
# Error en la iteración: 58 tensor(1.2752, grad_fn=<NllLossBackward>)
# Error en la iteración: 59 tensor(1.2639, grad_fn=<NllLossBackward>)
# Error en la iteración: 60 tensor(1.2590, grad_fn=<NllLossBackward>)
# Error en la iteración: 61 tensor(1.2559, grad_fn=<NllLossBackward>)
# Error en la iteración: 62 tensor(1.2491, grad_fn=<NllLossBackward>)
# Error en la iteración: 63 tensor(1.2690, grad_fn=<NllLossBackward>)
# Error en la iteración: 64 tensor(1.2457, grad_fn=<NllLossBackward>)
# Error en la iteración: 65 tensor(1.2412, grad_fn=<NllLossBackward>)
# Error en la iteración: 66 tensor(1.2771, grad_fn=<NllLossBackward>)
# Error en la iteración: 67 tensor(1.2548, grad_fn=<NllLossBackward>)
# Error en la iteración: 68 tensor(1.2406, grad_fn=<NllLossBackward>)
# Error en la iteración: 69 tensor(1.2320, grad_fn=<NllLossBackward>)
# Error en la iteración: 70 tensor(1.2672, grad_fn=<NllLossBackward>)
# Error en la iteración: 71 tensor(1.2536, grad_fn=<NllLossBackward>)
# Error en la iteración: 72 tensor(1.2344, grad_fn=<NllLossBackward>)
# Error en la iteración: 73 tensor(1.2119, grad_fn=<NllLossBackward>)
# Error en la iteración: 74 tensor(1.2068, grad_fn=<NllLossBackward>)
# Error en la iteración: 75 tensor(1.2045, grad_fn=<NllLossBackward>)
# Error en la iteración: 76 tensor(1.2026, grad_fn=<NllLossBackward>)
# Error en la iteración: 77 tensor(1.2251, grad_fn=<NllLossBackward>)
# Error en la iteración: 78 tensor(1.2153, grad_fn=<NllLossBackward>)
# Error en la iteración: 79 tensor(1.2493, grad_fn=<NllLossBackward>)
# Error en la iteración: 80 tensor(1.2179, grad_fn=<NllLossBackward>)
# Error en la iteración: 81 tensor(1.1963, grad_fn=<NllLossBackward>)
# Error en la iteración: 82 tensor(1.1997, grad_fn=<NllLossBackward>)
# Error en la iteración: 83 tensor(1.1912, grad_fn=<NllLossBackward>)
# Error en la iteración: 84 tensor(1.2007, grad_fn=<NllLossBackward>)
# Error en la iteración: 85 tensor(1.1712, grad_fn=<NllLossBackward>)
# Error en la iteración: 86 tensor(1.1737, grad_fn=<NllLossBackward>)
# Error en la iteración: 87 tensor(1.1861, grad_fn=<NllLossBackward>)
# Error en la iteración: 88 tensor(1.1672, grad_fn=<NllLossBackward>)
# Error en la iteración: 89 tensor(1.1783, grad_fn=<NllLossBackward>)
# Error en la iteración: 90 tensor(1.1542, grad_fn=<NllLossBackward>)
# Error en la iteración: 91 tensor(1.1503, grad_fn=<NllLossBackward>)
# Error en la iteración: 92 tensor(1.1532, grad_fn=<NllLossBackward>)
# Error en la iteración: 93 tensor(1.1572, grad_fn=<NllLossBackward>)
# Error en la iteración: 94 tensor(1.1527, grad_fn=<NllLossBackward>)
# Error en la iteración: 95 tensor(1.1709, grad_fn=<NllLossBackward>)
# Error en la iteración: 96 tensor(1.1667, grad_fn=<NllLossBackward>)
# Error en la iteración: 97 tensor(1.1720, grad_fn=<NllLossBackward>)
# Error en la iteración: 98 tensor(1.1563, grad_fn=<NllLossBackward>)
# Error en la iteración: 99 tensor(1.1364, grad_fn=<NllLossBackward>)
# Error en la iteración: 100 tensor(1.1514, grad_fn=<NllLossBackward>)
# Error en la iteración: 101 tensor(1.1543, grad_fn=<NllLossBackward>)
# Error en la iteración: 102 tensor(1.1357, grad_fn=<NllLossBackward>)
# Error en la iteración: 103 tensor(1.1555, grad_fn=<NllLossBackward>)
# Error en la iteración: 104 tensor(1.1301, grad_fn=<NllLossBackward>)
# Error en la iteración: 105 tensor(1.1390, grad_fn=<NllLossBackward>)
# Error en la iteración: 106 tensor(1.1240, grad_fn=<NllLossBackward>)
# Error en la iteración: 107 tensor(1.1346, grad_fn=<NllLossBackward>)
# Error en la iteración: 108 tensor(1.1087, grad_fn=<NllLossBackward>)
# Error en la iteración: 109 tensor(1.1240, grad_fn=<NllLossBackward>)
# Error en la iteración: 110 tensor(1.1002, grad_fn=<NllLossBackward>)
# Error en la iteración: 111 tensor(1.1347, grad_fn=<NllLossBackward>)
# Error en la iteración: 112 tensor(1.1100, grad_fn=<NllLossBackward>)
# Error en la iteración: 113 tensor(1.1271, grad_fn=<NllLossBackward>)
# Error en la iteración: 114 tensor(1.1013, grad_fn=<NllLossBackward>)
# Error en la iteración: 115 tensor(1.1256, grad_fn=<NllLossBackward>)
# Error en la iteración: 116 tensor(1.0981, grad_fn=<NllLossBackward>)
# Error en la iteración: 117 tensor(1.1242, grad_fn=<NllLossBackward>)
# Error en la iteración: 118 tensor(1.1364, grad_fn=<NllLossBackward>)
# Error en la iteración: 119 tensor(1.1566, grad_fn=<NllLossBackward>)
# Error en la iteración: 120 tensor(1.1878, grad_fn=<NllLossBackward>)
# Error en la iteración: 121 tensor(1.1177, grad_fn=<NllLossBackward>)
# Error en la iteración: 122 tensor(1.1193, grad_fn=<NllLossBackward>)
# Error en la iteración: 123 tensor(1.0948, grad_fn=<NllLossBackward>)
# Error en la iteración: 124 tensor(1.0851, grad_fn=<NllLossBackward>)
# Error en la iteración: 125 tensor(1.0860, grad_fn=<NllLossBackward>)
# Error en la iteración: 126 tensor(1.0804, grad_fn=<NllLossBackward>)
# Error en la iteración: 127 tensor(1.2002, grad_fn=<NllLossBackward>)
# Error en la iteración: 128 tensor(1.0811, grad_fn=<NllLossBackward>)
# Error en la iteración: 129 tensor(1.0685, grad_fn=<NllLossBackward>)
# Error en la iteración: 130 tensor(1.0642, grad_fn=<NllLossBackward>)
# Error en la iteración: 131 tensor(1.0526, grad_fn=<NllLossBackward>)
# Error en la iteración: 132 tensor(1.0378, grad_fn=<NllLossBackward>)
# Error en la iteración: 133 tensor(1.0335, grad_fn=<NllLossBackward>)
# Error en la iteración: 134 tensor(1.0220, grad_fn=<NllLossBackward>)
# Error en la iteración: 135 tensor(1.0141, grad_fn=<NllLossBackward>)
# Error en la iteración: 136 tensor(1.0078, grad_fn=<NllLossBackward>)
# Error en la iteración: 137 tensor(1.0041, grad_fn=<NllLossBackward>)
# Error en la iteración: 138 tensor(0.9982, grad_fn=<NllLossBackward>)
# Error en la iteración: 139 tensor(0.9930, grad_fn=<NllLossBackward>)
# Error en la iteración: 140 tensor(1.0021, grad_fn=<NllLossBackward>)
# Error en la iteración: 141 tensor(1.0182, grad_fn=<NllLossBackward>)
# Error en la iteración: 142 tensor(1.0221, grad_fn=<NllLossBackward>)
# Error en la iteración: 143 tensor(1.0177, grad_fn=<NllLossBackward>)
# Error en la iteración: 144 tensor(1.0112, grad_fn=<NllLossBackward>)
# Error en la iteración: 145 tensor(1.0257, grad_fn=<NllLossBackward>)
# Error en la iteración: 146 tensor(1.0127, grad_fn=<NllLossBackward>)
# Error en la iteración: 147 tensor(0.9995, grad_fn=<NllLossBackward>)
# Error en la iteración: 148 tensor(0.9920, grad_fn=<NllLossBackward>)
# Error en la iteración: 149 tensor(0.9902, grad_fn=<NllLossBackward>)
# Error en la iteración: 150 tensor(0.9875, grad_fn=<NllLossBackward>)
# Error en la iteración: 151 tensor(0.9802, grad_fn=<NllLossBackward>)
# Error en la iteración: 152 tensor(1.0166, grad_fn=<NllLossBackward>)
# Error en la iteración: 153 tensor(1.0045, grad_fn=<NllLossBackward>)
# Error en la iteración: 154 tensor(1.0728, grad_fn=<NllLossBackward>)
# Error en la iteración: 155 tensor(1.0190, grad_fn=<NllLossBackward>)
# Error en la iteración: 156 tensor(1.0229, grad_fn=<NllLossBackward>)
# Error en la iteración: 157 tensor(1.0062, grad_fn=<NllLossBackward>)
# Error en la iteración: 158 tensor(0.9887, grad_fn=<NllLossBackward>)
# Error en la iteración: 159 tensor(0.9840, grad_fn=<NllLossBackward>)
# Error en la iteración: 160 tensor(0.9658, grad_fn=<NllLossBackward>)
# Error en la iteración: 161 tensor(0.9522, grad_fn=<NllLossBackward>)
# Error en la iteración: 162 tensor(0.9409, grad_fn=<NllLossBackward>)
# Error en la iteración: 163 tensor(0.9429, grad_fn=<NllLossBackward>)
# Error en la iteración: 164 tensor(0.9468, grad_fn=<NllLossBackward>)
# Error en la iteración: 165 tensor(0.9464, grad_fn=<NllLossBackward>)
# Error en la iteración: 166 tensor(0.9368, grad_fn=<NllLossBackward>)
# Error en la iteración: 167 tensor(0.9236, grad_fn=<NllLossBackward>)
# Error en la iteración: 168 tensor(0.9430, grad_fn=<NllLossBackward>)
# Error en la iteración: 169 tensor(0.9711, grad_fn=<NllLossBackward>)
# Error en la iteración: 170 tensor(0.9563, grad_fn=<NllLossBackward>)
# Error en la iteración: 171 tensor(0.9587, grad_fn=<NllLossBackward>)
# Error en la iteración: 172 tensor(0.9398, grad_fn=<NllLossBackward>)
# Error en la iteración: 173 tensor(0.9329, grad_fn=<NllLossBackward>)
# Error en la iteración: 174 tensor(0.9301, grad_fn=<NllLossBackward>)
# Error en la iteración: 175 tensor(0.9109, grad_fn=<NllLossBackward>)
# Error en la iteración: 176 tensor(0.9220, grad_fn=<NllLossBackward>)
# Error en la iteración: 177 tensor(0.9034, grad_fn=<NllLossBackward>)
# Error en la iteración: 178 tensor(0.9388, grad_fn=<NllLossBackward>)
# Error en la iteración: 179 tensor(0.8997, grad_fn=<NllLossBackward>)
# Error en la iteración: 180 tensor(0.8958, grad_fn=<NllLossBackward>)
# Error en la iteración: 181 tensor(0.9078, grad_fn=<NllLossBackward>)
# Error en la iteración: 182 tensor(0.9120, grad_fn=<NllLossBackward>)
# Error en la iteración: 183 tensor(0.9036, grad_fn=<NllLossBackward>)
# Error en la iteración: 184 tensor(0.9009, grad_fn=<NllLossBackward>)
# Error en la iteración: 185 tensor(0.9061, grad_fn=<NllLossBackward>)
# Error en la iteración: 186 tensor(0.9022, grad_fn=<NllLossBackward>)
# Error en la iteración: 187 tensor(0.8979, grad_fn=<NllLossBackward>)
# Error en la iteración: 188 tensor(0.8759, grad_fn=<NllLossBackward>)
# Error en la iteración: 189 tensor(0.8828, grad_fn=<NllLossBackward>)
# Error en la iteración: 190 tensor(0.9088, grad_fn=<NllLossBackward>)
# Error en la iteración: 191 tensor(0.9254, grad_fn=<NllLossBackward>)
# Error en la iteración: 192 tensor(0.9190, grad_fn=<NllLossBackward>)
# Error en la iteración: 193 tensor(0.9617, grad_fn=<NllLossBackward>)
# Error en la iteración: 194 tensor(0.9530, grad_fn=<NllLossBackward>)
# Error en la iteración: 195 tensor(0.9510, grad_fn=<NllLossBackward>)
# Error en la iteración: 196 tensor(0.9768, grad_fn=<NllLossBackward>)
# Error en la iteración: 197 tensor(0.9255, grad_fn=<NllLossBackward>)
# Error en la iteración: 198 tensor(0.9717, grad_fn=<NllLossBackward>)
# Error en la iteración: 199 tensor(1.0560, grad_fn=<NllLossBackward>)

# %% [markdown]
# # Precisión

# %% [markdown]
# ## Precisión en el conjunto de entrenamiento.

# %%
nn_Musica.accurNet(trainset)
# Out:
# 61.097781362629284

# %% [markdown]
# ## Matriz de confusión para el conjunto de entrenamiento.

# %%
nn_Musica.confusion(trainset, 22)

# %% [markdown]
# ## Precisión en el conjunto de prueba.

# %%
nn_Musica.accurNet(testset)
# Out:
# 50.36687631027254

# %% [markdown]
# ## Matriz de confusión para el conjunto de prueba.

# %%
nn_Musica.confusion(testset, 22)

# %% [markdown]
# # Guardado del modelo.
# Finalmente guardamos el modelo si se desean hacer pruebas posteriores y evitar el entrenamiento otra vez.

# %%
torch.save(nn_Musica.state_dict(), 'model/model')

# %% [markdown]
# # Cargar el modelo
# Si se desea cargar el modelo basta con ejecutar las siguientes instrucciones.

# %%
nn_Musica_2 = Musica(29, 350, 22)
nn_Musica_2.load_state_dict(torch.load('model/model'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Conclusiones sobre el proyecto
#
# TODO: Sandy
